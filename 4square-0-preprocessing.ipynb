# %% [markdown]
# # STEP 0 - Preprocessing of the Foursquare DataSet
#
# Here, the dataset is analyzed and afterwards preprocessed.

# %% [markdown]
# ## Imports

# %%
import pandas as pd
from sqlalchemy import create_engine
import numpy as np

nyc_venues = create_engine('sqlite:///_nyc_venues.db')

# %% [markdown]
# ## Data Analysis
#
# First, we read the dataset into a database in order to get a general understanding. We have the columns:
# * user_id
# * venue
# * category_id
# * category_name
# * latitude
# * longitude
# * time_offset
# * time

# %%
df = pd.read_csv("./4square/dataset_TSMC2014_NYC.txt", sep="\t",
                 names=["user_id", "venue", "category_id", "category_name",
                        "latitude", "longitude", "time_offset", "time"])
print(df.head(10))

df.to_sql('nyc_venues', con=nyc_venues, if_exists="replace")
# Out:
#    user_id                     venue               category_id  \
# 0      470  49bbd6c0f964a520f4531fe3  4bf58dd8d48988d127951735
# 1      979  4a43c0aef964a520c6a61fe3  4bf58dd8d48988d1df941735
# 2       69  4c5cc7b485a1e21e00d35711  4bf58dd8d48988d103941735
# 3      395  4bc7086715a7ef3bef9878da  4bf58dd8d48988d104941735
# 4       87  4cf2c5321d18a143951b5cec  4bf58dd8d48988d1cb941735
# 5      484  4b5b981bf964a520900929e3  4bf58dd8d48988d118951735
# 6      642  4ab966c3f964a5203c7f20e3  4bf58dd8d48988d1e0931735
# 7      292  4d0cc47f903d37041864bf55  4bf58dd8d48988d12b951735
# 8      428  4ce1863bc4f6a35d8bd2db6c  4bf58dd8d48988d103941735
# 9      877  4be319b321d5a59352311811  4bf58dd8d48988d10a951735
#
#          category_name   latitude  longitude  time_offset  \
# 0  Arts & Crafts Store  40.719810 -74.002581         -240
# 1               Bridge  40.606800 -74.044170         -240
# 2       Home (private)  40.716162 -73.883070         -240
# 3       Medical Center  40.745164 -73.982519         -240
# 4           Food Truck  40.740104 -73.989658         -240
# 5    Food & Drink Shop  40.690427 -73.954687         -240
# 6          Coffee Shop  40.751591 -73.974121         -240
# 7          Bus Station  40.779422 -73.955341         -240
# 8       Home (private)  40.619151 -74.035888         -240
# 9                 Bank  40.619006 -73.990375         -240
#
#                              time
# 0  Tue Apr 03 18:00:09 +0000 2012
# 1  Tue Apr 03 18:00:25 +0000 2012
# 2  Tue Apr 03 18:02:24 +0000 2012
# 3  Tue Apr 03 18:02:41 +0000 2012
# 4  Tue Apr 03 18:03:00 +0000 2012
# 5  Tue Apr 03 18:04:00 +0000 2012
# 6  Tue Apr 03 18:04:38 +0000 2012
# 7  Tue Apr 03 18:04:42 +0000 2012
# 8  Tue Apr 03 18:06:18 +0000 2012
# 9  Tue Apr 03 18:06:19 +0000 2012

# %%
res=pd.read_sql_query('SELECT count(*) FROM nyc_venues', nyc_venues)
print(res)
# Out:
#    count(*)
# 0    227428

# %% [markdown]
# There are 227.428 rows in the dataset. Those are all checkins from users in NYC.

# %%
res=pd.read_sql_query('SELECT count(*) FROM nyc_venues '+
        'WHERE time IS NULL '+
        'OR user_id IS NULL ' +
        'OR venue IS NULL ' +
        'OR category_id IS NULL '+
        'OR category_name IS NULL ', nyc_venues)
print(res)
# Out:
#    count(*)
# 0         0

# %%
res=pd.read_sql_query('SELECT count(*)' +
        'FROM nyc_venues WHERE ((latitude IS null) OR ' +
        '(latitude = 0.000000) OR (longitude IS null) OR ' +
        '(longitude = 0.000000))', nyc_venues)

print(res)
# Out:
#    count(*)
# 0         0

# %% [markdown]
# It can be concluded that there are no incomplete or invalid rows.
#
# Next, the user data is analyzed. Here, the number of checkins of the best and worst users are important measurements.

# %%
res=pd.read_sql_query('SELECT user_id, "count" FROM ' +
            '(SELECT count(user_id) as "count", user_id FROM nyc_venues GROUP BY user_id)' +
            'ORDER BY "count" DESC LIMIT 10', nyc_venues)

print(res)
# Out:
#    user_id  count
# 0      293   2697
# 1      185   2079
# 2      354   2061
# 3      315   1682
# 4       84   1376
# 5      349   1369
# 6      384   1116
# 7      974   1107
# 8      768   1096
# 9      445    952

# %%
res=pd.read_sql_query('SELECT user_id, "count" FROM ' +
            '(SELECT count(user_id) as "count", user_id FROM nyc_venues GROUP BY user_id)' +
            'ORDER BY "count" ASC LIMIT 10', nyc_venues)

print(res)
# Out:
#    user_id  count
# 0       18    100
# 1       92    100
# 2      247    100
# 3      268    100
# 4      324    100
# 5      369    100
# 6      394    100
# 7      426    100
# 8      451    100
# 9      671    100

# %%
res=pd.read_sql_query('SELECT AVG(count) FROM (SELECT user_id, "count" FROM ' +
            '(SELECT count(user_id) as "count", user_id FROM nyc_venues GROUP BY user_id))', nyc_venues)

print(res)
# Out:
#    AVG(count)
# 0  209.998153

# %%
res =pd.read_sql_query('SELECT count(distinct(user_id)) FROM nyc_venues', nyc_venues)

print(res)
# Out:
#    count(distinct(user_id))
# 0                      1083

# %% [markdown]
# There are 1083 users in the dataset.
# The best users have over 2000 checkins. An average user has over 200 checkins.
# This number can be seen as reasonable. The locations also have to be checked.

# %%
res=pd.read_sql_query('SELECT count(distinct(venue)) FROM nyc_venues', nyc_venues)

print(res)
# Out:
#    count(distinct(venue))
# 0                   38333

# %%
res=pd.read_sql_query('SELECT AVG(a) FROM (' +
    'SELECT count(distinct(venue)) as a, user_id FROM nyc_venues GROUP BY user_id) ' , nyc_venues)

print(res)
# Out:
#       AVG(a)
# 0  84.048015

# %% [markdown]
# There are 38.333 different venues. Every user visits 84 venues on average.
# It has to be considered that every user only does 200 checkins on average.
# In perspective, this number is too high.
# It can be expected that a model trained on so many locations will be very inaccurate.

# %%
res=pd.read_sql_query('SELECT time, category_name FROM nyc_venues WHERE user_id=293 LIMIT 50', nyc_venues)

print(res)
# Out:
#                               time                  category_name
# 0   Tue Apr 03 23:56:43 +0000 2012                         Subway
# 1   Wed Apr 04 00:19:13 +0000 2012           Other Great Outdoors
# 2   Wed Apr 04 00:19:44 +0000 2012                            Bar
# 3   Wed Apr 04 00:21:12 +0000 2012                     Smoke Shop
# 4   Wed Apr 04 04:53:06 +0000 2012                   Neighborhood
# 5   Wed Apr 04 04:53:36 +0000 2012           Other Great Outdoors
# 6   Wed Apr 04 05:08:28 +0000 2012                    Bus Station
# 7   Wed Apr 04 15:38:43 +0000 2012                 Home (private)
# 8   Wed Apr 04 16:16:45 +0000 2012                 Home (private)
# 9   Wed Apr 04 16:18:34 +0000 2012                 General Travel
# 10  Wed Apr 04 16:20:07 +0000 2012                         Subway
# 11  Wed Apr 04 17:38:40 +0000 2012                         Subway
# 12  Wed Apr 04 17:40:06 +0000 2012              Electronics Store
# 13  Wed Apr 04 17:40:29 +0000 2012                         Office
# 14  Wed Apr 04 18:14:47 +0000 2012                         Subway
# 15  Wed Apr 04 18:16:52 +0000 2012                           Park
# 16  Wed Apr 04 18:18:19 +0000 2012  Paper / Office Supplies Store
# 17  Wed Apr 04 23:55:49 +0000 2012                           Road
# 18  Wed Apr 04 23:56:33 +0000 2012                         Subway
# 19  Thu Apr 05 00:18:50 +0000 2012           Other Great Outdoors
# 20  Thu Apr 05 00:19:52 +0000 2012                   Neighborhood
# 21  Thu Apr 05 00:20:43 +0000 2012                     Smoke Shop
# 22  Fri Apr 06 15:35:00 +0000 2012                 Home (private)
# 23  Fri Apr 06 15:35:52 +0000 2012                 Home (private)
# 24  Fri Apr 06 16:13:52 +0000 2012                 Home (private)
# 25  Fri Apr 06 16:20:37 +0000 2012              Food & Drink Shop
# 26  Fri Apr 06 16:37:17 +0000 2012           Drugstore / Pharmacy
# 27  Fri Apr 06 16:38:12 +0000 2012                    Bus Station
# 28  Sat Apr 07 00:14:39 +0000 2012           Other Great Outdoors
# 29  Sat Apr 07 00:15:58 +0000 2012                     Smoke Shop
# 30  Sat Apr 07 19:38:56 +0000 2012                 Home (private)
# 31  Sat Apr 07 19:39:33 +0000 2012                 Home (private)
# 32  Sat Apr 07 20:56:31 +0000 2012            American Restaurant
# 33  Sat Apr 07 22:57:10 +0000 2012                 Home (private)
# 34  Sat Apr 07 23:33:21 +0000 2012                 General Travel
# 35  Sat Apr 07 23:50:39 +0000 2012           Other Great Outdoors
# 36  Sat Apr 07 23:52:25 +0000 2012                   Neighborhood
# 37  Sat Apr 07 23:53:26 +0000 2012                     Smoke Shop
# 38  Sun Apr 08 07:40:42 +0000 2012           Other Great Outdoors
# 39  Sun Apr 08 07:41:35 +0000 2012                   Neighborhood
# 40  Sun Apr 08 08:33:20 +0000 2012                    Bus Station
# 41  Sun Apr 08 19:31:22 +0000 2012          General Entertainment
# 42  Mon Apr 09 11:57:14 +0000 2012                 Home (private)
# 43  Mon Apr 09 11:57:30 +0000 2012                 Home (private)
# 44  Mon Apr 09 12:32:09 +0000 2012                 Home (private)
# 45  Mon Apr 09 12:56:28 +0000 2012                    Bus Station
# 46  Mon Apr 09 16:26:07 +0000 2012                 General Travel
# 47  Mon Apr 09 16:27:46 +0000 2012                         Subway
# 48  Mon Apr 09 17:11:15 +0000 2012                           Park
# 49  Tue Apr 10 00:22:25 +0000 2012           Other Great Outdoors

# %% [markdown]
# The checkin times are as expected. On most days, there are many checkins.
# The data is continuous and can thus be used.

# %% [markdown]
# In order to decrease the number of locations, the categories can be used instead.
# As a result the prediction becomes more semantic (what kind of place) instead of physical (latitude/longitude).

# %%
res=pd.read_sql_query('SELECT DISTINCT(category_id) AS ID, category_name FROM nyc_venues', nyc_venues)
print(res)
# Out:
#                            ID         category_name
# 0    4bf58dd8d48988d127951735   Arts & Crafts Store
# 1    4bf58dd8d48988d1df941735                Bridge
# 2    4bf58dd8d48988d103941735        Home (private)
# 3    4bf58dd8d48988d104941735        Medical Center
# 4    4bf58dd8d48988d1cb941735            Food Truck
# ..                        ...                   ...
# 395  5032897c91d4c4b30a586d69           Pet Service
# 396  4f04b08c2fb6e1c99f3db0bd    Miscellaneous Shop
# 397  4eb1c0ed3b7b52c0e1adc2ea              Ski Area
# 398  5032856091d4c4b30a586d63                Office
# 399  5032848691d4c4b30a586d61  Other Great Outdoors
#
# [400 rows x 2 columns]

# %%
res=pd.read_sql_query('SELECT COUNT(DISTINCT(category_id)) FROM nyc_venues', nyc_venues)

print(res)
# Out:
#    COUNT(DISTINCT(category_id))
# 0                           400

# %%
res=pd.read_sql_query('SELECT category_name, COUNT(*) FROM nyc_venues GROUP BY category_id ORDER BY COUNT(*) DESC', nyc_venues)

print(res)
# Out:
#             category_name  COUNT(*)
# 0          Home (private)     15334
# 1                  Office      9614
# 2                  Subway      9348
# 3             Coffee Shop      7510
# 4                     Bar      6188
# ..                    ...       ...
# 395  Other Great Outdoors         1
# 396              Ski Area         1
# 397              Ski Area         1
# 398    Miscellaneous Shop         1
# 399          Music School         1
#
# [400 rows x 2 columns]

# %%
res=pd.read_sql_query('SELECT a.* FROM (SELECT category_name, COUNT(*) AS num FROM nyc_venues GROUP BY category_name ORDER BY num DESC) a WHERE a.num < 10', nyc_venues)
print(res)
# Out:
#                category_name  num
# 0   Bike Rental / Bike Share    9
# 1      Portuguese Restaurant    9
# 2                 Distillery    8
# 3              Internet Cafe    6
# 4     Gluten-free Restaurant    5
# 5          Afghan Restaurant    4
# 6             Sorority House    4
# 7                Pet Service    3
# 8                     Castle    2
# 9            Motorcycle Shop    2
# 10           Photography Lab    2
# 11              Music School    1

# %% [markdown]
# There are 400 different categories of venues in the dataset.
# This number still seems quite high.
# Especially as some categories seem to be duplicated or used only for a small number of checkins.
# A possible solution is to group them in super categories.

# %% [markdown]
# ## Pre-processing
#
# The categories are exported in a .csv file custom uber categories are created.
# This is done for every category_name instead of the id in order to account for duplicates.

# %%
unprocessed = df.copy()

# %%
res=pd.read_sql_query('SELECT category_name, COUNT(*) FROM nyc_venues GROUP BY category_name ORDER BY COUNT(*) DESC', nyc_venues)
res.to_csv('././4square/categories.csv', index=False)

# %%
uber = create_engine('sqlite:///_uber.db')
df = pd.read_csv("./4square/uber_cat.csv", sep=",")

print(df.head(10))

df.to_sql('uber', con=uber, if_exists="replace")
# Out:
#       uber_category         category_name  COUNT(*)
# 0               Bar                   Bar     15978
# 1              Home        Home (private)     15382
# 2              Work                Office     12740
# 3  Public Transport                Subway      9348
# 4            Sports  Gym / Fitness Center      9171
# 5              Cafe           Coffee Shop      7510
# 6           Grocery     Food & Drink Shop      6596
# 7  Public Transport         Train Station      6408
# 8              Park                  Park      4804
# 9              Home          Neighborhood      4604

# %%
res=pd.read_sql_query('SELECT DISTINCT uber_category, COUNT(*) FROM uber GROUP BY uber_category ORDER BY COUNT(*) DESC', uber)
print(res)
# Out:
#             uber_category  COUNT(*)
# 0              Restaurant        68
# 1                Shopping        30
# 2           Entertainment        18
# 3                  School        17
# 4                 Culture        12
# 5                 Service        11
# 6                  Snacks        11
# 7        Public Transport        10
# 8           Misc Shopping         8
# 9                Outdoors         7
# 10               Religion         7
# 11              Cosmetics         5
# 12                  Event         5
# 13                   Home         5
# 14         Infrastructure         5
# 15                   Misc         5
# 16                   Cafe         4
# 17  Gas Station / Parking         3
# 18             Government         3
# 19                   Park         3
# 20                 Sports         3
# 21                   Work         3
# 22                    Bar         2
# 23                Grocery         2
# 24                Medical         2
# 25               Building         1
# 26                  Hotel         1

# %% [markdown]
# There are 27 uber categories that group the former semantically similar categories together.

# %% [markdown]
# Next, the uber categories are joined with our regular dataset.

# %%
ubers=pd.read_sql_query('SELECT DISTINCT uber_category, category_name FROM uber', uber)

# %%
merged = unprocessed.merge(ubers, on='category_name', suffixes=('', '_y'), how='left')
merged.head(10)
# Out:
#    user_id                     venue               category_id  \
# 0      470  49bbd6c0f964a520f4531fe3  4bf58dd8d48988d127951735
# 1      979  4a43c0aef964a520c6a61fe3  4bf58dd8d48988d1df941735
# 2       69  4c5cc7b485a1e21e00d35711  4bf58dd8d48988d103941735
# 3      395  4bc7086715a7ef3bef9878da  4bf58dd8d48988d104941735
# 4       87  4cf2c5321d18a143951b5cec  4bf58dd8d48988d1cb941735
# 5      484  4b5b981bf964a520900929e3  4bf58dd8d48988d118951735
# 6      642  4ab966c3f964a5203c7f20e3  4bf58dd8d48988d1e0931735
# 7      292  4d0cc47f903d37041864bf55  4bf58dd8d48988d12b951735
# 8      428  4ce1863bc4f6a35d8bd2db6c  4bf58dd8d48988d103941735
# 9      877  4be319b321d5a59352311811  4bf58dd8d48988d10a951735
#
#          category_name   latitude  longitude  time_offset  \
# 0  Arts & Crafts Store  40.719810 -74.002581         -240
# 1               Bridge  40.606800 -74.044170         -240
# 2       Home (private)  40.716162 -73.883070         -240
# 3       Medical Center  40.745164 -73.982519         -240
# 4           Food Truck  40.740104 -73.989658         -240
# 5    Food & Drink Shop  40.690427 -73.954687         -240
# 6          Coffee Shop  40.751591 -73.974121         -240
# 7          Bus Station  40.779422 -73.955341         -240
# 8       Home (private)  40.619151 -74.035888         -240
# 9                 Bank  40.619006 -73.990375         -240
#
#                              time     uber_category
# 0  Tue Apr 03 18:00:09 +0000 2012          Shopping
# 1  Tue Apr 03 18:00:25 +0000 2012    Infrastructure
# 2  Tue Apr 03 18:02:24 +0000 2012              Home
# 3  Tue Apr 03 18:02:41 +0000 2012           Medical
# 4  Tue Apr 03 18:03:00 +0000 2012            Snacks
# 5  Tue Apr 03 18:04:00 +0000 2012           Grocery
# 6  Tue Apr 03 18:04:38 +0000 2012              Cafe
# 7  Tue Apr 03 18:04:42 +0000 2012  Public Transport
# 8  Tue Apr 03 18:06:18 +0000 2012              Home
# 9  Tue Apr 03 18:06:19 +0000 2012           Service

# %% [markdown]
# The first processed dataset is supposed to be minimalistic.
# It should contain the time components and the uber category.
# The time is split in different features.
# The reason for that is a more accurate model training.
# For example, it is easier to distinguish daily, monthly and hourly trends.
# Week days are also important.
# Especially working days and weekends can be distinguished (maybe by addition of a dedicated feature, i.e. "is_weekend").
# The user information has to be kept, too.
# Because the data must be sequenced for every user.

# %%
def is_weekend(week_day):
    return week_day > 4

# %%
merged["time"] = pd.to_datetime(merged["time"])

merged["month"] = merged.time.dt.month
merged["day"] = merged.time.dt.day
merged["clock"] = merged.time.dt.hour + merged.time.dt.minute/60 + merged.time.dt.second/3600
merged["week_day"] = merged.time.dt.dayofweek
merged["is_weekend"] = merged.apply(lambda x: is_weekend(x["week_day"]), axis=1)

# %% [markdown]
# The categories are transformed in unique ids in order to save space and make learning easier.

# %%
merged['cat_id'] = merged.groupby('uber_category', sort=False).ngroup()

# %%
merged.head(10)
# Out:
#    user_id                     venue               category_id  \
# 0      470  49bbd6c0f964a520f4531fe3  4bf58dd8d48988d127951735
# 1      979  4a43c0aef964a520c6a61fe3  4bf58dd8d48988d1df941735
# 2       69  4c5cc7b485a1e21e00d35711  4bf58dd8d48988d103941735
# 3      395  4bc7086715a7ef3bef9878da  4bf58dd8d48988d104941735
# 4       87  4cf2c5321d18a143951b5cec  4bf58dd8d48988d1cb941735
# 5      484  4b5b981bf964a520900929e3  4bf58dd8d48988d118951735
# 6      642  4ab966c3f964a5203c7f20e3  4bf58dd8d48988d1e0931735
# 7      292  4d0cc47f903d37041864bf55  4bf58dd8d48988d12b951735
# 8      428  4ce1863bc4f6a35d8bd2db6c  4bf58dd8d48988d103941735
# 9      877  4be319b321d5a59352311811  4bf58dd8d48988d10a951735
#
#          category_name   latitude  longitude  time_offset  \
# 0  Arts & Crafts Store  40.719810 -74.002581         -240
# 1               Bridge  40.606800 -74.044170         -240
# 2       Home (private)  40.716162 -73.883070         -240
# 3       Medical Center  40.745164 -73.982519         -240
# 4           Food Truck  40.740104 -73.989658         -240
# 5    Food & Drink Shop  40.690427 -73.954687         -240
# 6          Coffee Shop  40.751591 -73.974121         -240
# 7          Bus Station  40.779422 -73.955341         -240
# 8       Home (private)  40.619151 -74.035888         -240
# 9                 Bank  40.619006 -73.990375         -240
#
#                        time     uber_category  month  day      clock  \
# 0 2012-04-03 18:00:09+00:00          Shopping      4    3  18.002500
# 1 2012-04-03 18:00:25+00:00    Infrastructure      4    3  18.006944
# 2 2012-04-03 18:02:24+00:00              Home      4    3  18.040000
# 3 2012-04-03 18:02:41+00:00           Medical      4    3  18.044722
# 4 2012-04-03 18:03:00+00:00            Snacks      4    3  18.050000
# 5 2012-04-03 18:04:00+00:00           Grocery      4    3  18.066667
# 6 2012-04-03 18:04:38+00:00              Cafe      4    3  18.077222
# 7 2012-04-03 18:04:42+00:00  Public Transport      4    3  18.078333
# 8 2012-04-03 18:06:18+00:00              Home      4    3  18.105000
# 9 2012-04-03 18:06:19+00:00           Service      4    3  18.105278
#
#    week_day  is_weekend  cat_id
# 0         1       False       0
# 1         1       False       1
# 2         1       False       2
# 3         1       False       3
# 4         1       False       4
# 5         1       False       5
# 6         1       False       6
# 7         1       False       7
# 8         1       False       2
# 9         1       False       8

# %% [markdown]
# Temporal transformation is applied on the time components.
# This is done by sin/cos transformation.

# %%
merged['clock_sin'] = np.sin(2 * np.pi * merged['clock']/24.0)
merged['clock_cos'] = np.cos(2 * np.pi * merged['clock']/24.0)
merged['day_sin'] = np.sin(2 * np.pi * merged['day']/30.0)
merged['day_cos'] = np.cos(2 * np.pi * merged['day']/30.0)
merged['month_sin'] = np.sin(2 * np.pi * merged['month']/12.0)
merged['month_cos'] = np.cos(2 * np.pi * merged['month']/12.0)
merged['week_day_sin'] = np.sin(2 * np.pi * merged['week_day']/7.0)
merged['week_day_cos'] = np.cos(2 * np.pi * merged['week_day']/7.0)

# %% [markdown]
# The unnecessary columns are dropped and then the data is processed.

# %%
merged.drop(['clock', 'day', 'month', 'week_day', 'uber_category'], axis=1, inplace=True)

# %%
processed = merged.copy()
processed.head(10)
# Out:
#    user_id                     venue               category_id  \
# 0      470  49bbd6c0f964a520f4531fe3  4bf58dd8d48988d127951735
# 1      979  4a43c0aef964a520c6a61fe3  4bf58dd8d48988d1df941735
# 2       69  4c5cc7b485a1e21e00d35711  4bf58dd8d48988d103941735
# 3      395  4bc7086715a7ef3bef9878da  4bf58dd8d48988d104941735
# 4       87  4cf2c5321d18a143951b5cec  4bf58dd8d48988d1cb941735
# 5      484  4b5b981bf964a520900929e3  4bf58dd8d48988d118951735
# 6      642  4ab966c3f964a5203c7f20e3  4bf58dd8d48988d1e0931735
# 7      292  4d0cc47f903d37041864bf55  4bf58dd8d48988d12b951735
# 8      428  4ce1863bc4f6a35d8bd2db6c  4bf58dd8d48988d103941735
# 9      877  4be319b321d5a59352311811  4bf58dd8d48988d10a951735
#
#          category_name   latitude  longitude  time_offset  \
# 0  Arts & Crafts Store  40.719810 -74.002581         -240
# 1               Bridge  40.606800 -74.044170         -240
# 2       Home (private)  40.716162 -73.883070         -240
# 3       Medical Center  40.745164 -73.982519         -240
# 4           Food Truck  40.740104 -73.989658         -240
# 5    Food & Drink Shop  40.690427 -73.954687         -240
# 6          Coffee Shop  40.751591 -73.974121         -240
# 7          Bus Station  40.779422 -73.955341         -240
# 8       Home (private)  40.619151 -74.035888         -240
# 9                 Bank  40.619006 -73.990375         -240
#
#                        time  is_weekend  cat_id  clock_sin  clock_cos  \
# 0 2012-04-03 18:00:09+00:00       False       0  -1.000000   0.000654
# 1 2012-04-03 18:00:25+00:00       False       1  -0.999998   0.001818
# 2 2012-04-03 18:02:24+00:00       False       2  -0.999945   0.010472
# 3 2012-04-03 18:02:41+00:00       False       3  -0.999931   0.011708
# 4 2012-04-03 18:03:00+00:00       False       4  -0.999914   0.013090
# 5 2012-04-03 18:04:00+00:00       False       5  -0.999848   0.017452
# 6 2012-04-03 18:04:38+00:00       False       6  -0.999796   0.020215
# 7 2012-04-03 18:04:42+00:00       False       7  -0.999790   0.020506
# 8 2012-04-03 18:06:18+00:00       False       2  -0.999622   0.027485
# 9 2012-04-03 18:06:19+00:00       False       8  -0.999620   0.027558
#
#     day_sin   day_cos  month_sin  month_cos  week_day_sin  week_day_cos
# 0  0.587785  0.809017   0.866025       -0.5      0.781831       0.62349
# 1  0.587785  0.809017   0.866025       -0.5      0.781831       0.62349
# 2  0.587785  0.809017   0.866025       -0.5      0.781831       0.62349
# 3  0.587785  0.809017   0.866025       -0.5      0.781831       0.62349
# 4  0.587785  0.809017   0.866025       -0.5      0.781831       0.62349
# 5  0.587785  0.809017   0.866025       -0.5      0.781831       0.62349
# 6  0.587785  0.809017   0.866025       -0.5      0.781831       0.62349
# 7  0.587785  0.809017   0.866025       -0.5      0.781831       0.62349
# 8  0.587785  0.809017   0.866025       -0.5      0.781831       0.62349
# 9  0.587785  0.809017   0.866025       -0.5      0.781831       0.62349

# %% [markdown]
# Here, reduced dataset for the first model training is created.

# %%
reduced = processed.drop(['venue', 'category_id', 'category_name', 'latitude', 'longitude', 'time_offset', 'time', 'is_weekend'], axis=1, inplace=False)

reduced.head(10)
# Out:
#    user_id  cat_id  clock_sin  clock_cos   day_sin   day_cos  month_sin  \
# 0      470       0  -1.000000   0.000654  0.587785  0.809017   0.866025
# 1      979       1  -0.999998   0.001818  0.587785  0.809017   0.866025
# 2       69       2  -0.999945   0.010472  0.587785  0.809017   0.866025
# 3      395       3  -0.999931   0.011708  0.587785  0.809017   0.866025
# 4       87       4  -0.999914   0.013090  0.587785  0.809017   0.866025
# 5      484       5  -0.999848   0.017452  0.587785  0.809017   0.866025
# 6      642       6  -0.999796   0.020215  0.587785  0.809017   0.866025
# 7      292       7  -0.999790   0.020506  0.587785  0.809017   0.866025
# 8      428       2  -0.999622   0.027485  0.587785  0.809017   0.866025
# 9      877       8  -0.999620   0.027558  0.587785  0.809017   0.866025
#
#    month_cos  week_day_sin  week_day_cos
# 0       -0.5      0.781831       0.62349
# 1       -0.5      0.781831       0.62349
# 2       -0.5      0.781831       0.62349
# 3       -0.5      0.781831       0.62349
# 4       -0.5      0.781831       0.62349
# 5       -0.5      0.781831       0.62349
# 6       -0.5      0.781831       0.62349
# 7       -0.5      0.781831       0.62349
# 8       -0.5      0.781831       0.62349
# 9       -0.5      0.781831       0.62349

# %% [markdown]
# A bigger dataset with all the processed features is also created.
# For that purpose we map venues and category ids to smaller indices.

# %%
processed['venue_id'] = processed.groupby('venue', sort=False).ngroup()
processed['orig_cat_id'] = processed.groupby('category_id', sort=False).ngroup()
big = processed.drop(['venue', 'category_id', 'category_name', 'time_offset', 'time'], axis=1, inplace=False)

big.head(10)
# Out:
#    user_id   latitude  longitude  is_weekend  cat_id  clock_sin  clock_cos  \
# 0      470  40.719810 -74.002581       False       0  -1.000000   0.000654
# 1      979  40.606800 -74.044170       False       1  -0.999998   0.001818
# 2       69  40.716162 -73.883070       False       2  -0.999945   0.010472
# 3      395  40.745164 -73.982519       False       3  -0.999931   0.011708
# 4       87  40.740104 -73.989658       False       4  -0.999914   0.013090
# 5      484  40.690427 -73.954687       False       5  -0.999848   0.017452
# 6      642  40.751591 -73.974121       False       6  -0.999796   0.020215
# 7      292  40.779422 -73.955341       False       7  -0.999790   0.020506
# 8      428  40.619151 -74.035888       False       2  -0.999622   0.027485
# 9      877  40.619006 -73.990375       False       8  -0.999620   0.027558
#
#     day_sin   day_cos  month_sin  month_cos  week_day_sin  week_day_cos  \
# 0  0.587785  0.809017   0.866025       -0.5      0.781831       0.62349
# 1  0.587785  0.809017   0.866025       -0.5      0.781831       0.62349
# 2  0.587785  0.809017   0.866025       -0.5      0.781831       0.62349
# 3  0.587785  0.809017   0.866025       -0.5      0.781831       0.62349
# 4  0.587785  0.809017   0.866025       -0.5      0.781831       0.62349
# 5  0.587785  0.809017   0.866025       -0.5      0.781831       0.62349
# 6  0.587785  0.809017   0.866025       -0.5      0.781831       0.62349
# 7  0.587785  0.809017   0.866025       -0.5      0.781831       0.62349
# 8  0.587785  0.809017   0.866025       -0.5      0.781831       0.62349
# 9  0.587785  0.809017   0.866025       -0.5      0.781831       0.62349
#
#    venue_id  orig_cat_id
# 0         0            0
# 1         1            1
# 2         2            2
# 3         3            3
# 4         4            4
# 5         5            5
# 6         6            6
# 7         7            7
# 8         8            2
# 9         9            8

# %% [markdown]
# Move 'cat_id' to the first column (will be used as y -> prediction)

# %%
def move_first(df, column_name):
    fc = df.pop(column_name)
    df.insert(0, column_name, fc)

# %%
move_first(reduced, 'cat_id')
reduced.head(10)
# Out:
#    cat_id  user_id  clock_sin  clock_cos   day_sin   day_cos  month_sin  \
# 0       0      470  -1.000000   0.000654  0.587785  0.809017   0.866025
# 1       1      979  -0.999998   0.001818  0.587785  0.809017   0.866025
# 2       2       69  -0.999945   0.010472  0.587785  0.809017   0.866025
# 3       3      395  -0.999931   0.011708  0.587785  0.809017   0.866025
# 4       4       87  -0.999914   0.013090  0.587785  0.809017   0.866025
# 5       5      484  -0.999848   0.017452  0.587785  0.809017   0.866025
# 6       6      642  -0.999796   0.020215  0.587785  0.809017   0.866025
# 7       7      292  -0.999790   0.020506  0.587785  0.809017   0.866025
# 8       2      428  -0.999622   0.027485  0.587785  0.809017   0.866025
# 9       8      877  -0.999620   0.027558  0.587785  0.809017   0.866025
#
#    month_cos  week_day_sin  week_day_cos
# 0       -0.5      0.781831       0.62349
# 1       -0.5      0.781831       0.62349
# 2       -0.5      0.781831       0.62349
# 3       -0.5      0.781831       0.62349
# 4       -0.5      0.781831       0.62349
# 5       -0.5      0.781831       0.62349
# 6       -0.5      0.781831       0.62349
# 7       -0.5      0.781831       0.62349
# 8       -0.5      0.781831       0.62349
# 9       -0.5      0.781831       0.62349

# %%
move_first(big, 'cat_id')
big.head(10)
# Out:
#    cat_id  user_id   latitude  longitude  is_weekend  clock_sin  clock_cos  \
# 0       0      470  40.719810 -74.002581       False  -1.000000   0.000654
# 1       1      979  40.606800 -74.044170       False  -0.999998   0.001818
# 2       2       69  40.716162 -73.883070       False  -0.999945   0.010472
# 3       3      395  40.745164 -73.982519       False  -0.999931   0.011708
# 4       4       87  40.740104 -73.989658       False  -0.999914   0.013090
# 5       5      484  40.690427 -73.954687       False  -0.999848   0.017452
# 6       6      642  40.751591 -73.974121       False  -0.999796   0.020215
# 7       7      292  40.779422 -73.955341       False  -0.999790   0.020506
# 8       2      428  40.619151 -74.035888       False  -0.999622   0.027485
# 9       8      877  40.619006 -73.990375       False  -0.999620   0.027558
#
#     day_sin   day_cos  month_sin  month_cos  week_day_sin  week_day_cos  \
# 0  0.587785  0.809017   0.866025       -0.5      0.781831       0.62349
# 1  0.587785  0.809017   0.866025       -0.5      0.781831       0.62349
# 2  0.587785  0.809017   0.866025       -0.5      0.781831       0.62349
# 3  0.587785  0.809017   0.866025       -0.5      0.781831       0.62349
# 4  0.587785  0.809017   0.866025       -0.5      0.781831       0.62349
# 5  0.587785  0.809017   0.866025       -0.5      0.781831       0.62349
# 6  0.587785  0.809017   0.866025       -0.5      0.781831       0.62349
# 7  0.587785  0.809017   0.866025       -0.5      0.781831       0.62349
# 8  0.587785  0.809017   0.866025       -0.5      0.781831       0.62349
# 9  0.587785  0.809017   0.866025       -0.5      0.781831       0.62349
#
#    venue_id  orig_cat_id
# 0         0            0
# 1         1            1
# 2         2            2
# 3         3            3
# 4         4            4
# 5         5            5
# 6         6            6
# 7         7            7
# 8         8            2
# 9         9            8

# %% [markdown]
# Save the datasets to .csv files.

# %%
reduced.to_csv('./4square/processed_transformed.csv', index=False)
big.to_csv('./4square/processed_transformed_big.csv', index=False)

# %% [markdown]
# Create old dataset for legacy notebooks and trial runs with changed architectures.

# %%
# column order: user_id,cat_id,clock_sin,clock_cos,day_sin,day_cos,month_sin,month_cos,week_day_sin,week_day_cos
old = reduced.copy()
move_first(old, 'user_id')
old.head(10)
# Out:
#    user_id  cat_id  clock_sin  clock_cos   day_sin   day_cos  month_sin  \
# 0      470       0  -1.000000   0.000654  0.587785  0.809017   0.866025
# 1      979       1  -0.999998   0.001818  0.587785  0.809017   0.866025
# 2       69       2  -0.999945   0.010472  0.587785  0.809017   0.866025
# 3      395       3  -0.999931   0.011708  0.587785  0.809017   0.866025
# 4       87       4  -0.999914   0.013090  0.587785  0.809017   0.866025
# 5      484       5  -0.999848   0.017452  0.587785  0.809017   0.866025
# 6      642       6  -0.999796   0.020215  0.587785  0.809017   0.866025
# 7      292       7  -0.999790   0.020506  0.587785  0.809017   0.866025
# 8      428       2  -0.999622   0.027485  0.587785  0.809017   0.866025
# 9      877       8  -0.999620   0.027558  0.587785  0.809017   0.866025
#
#    month_cos  week_day_sin  week_day_cos
# 0       -0.5      0.781831       0.62349
# 1       -0.5      0.781831       0.62349
# 2       -0.5      0.781831       0.62349
# 3       -0.5      0.781831       0.62349
# 4       -0.5      0.781831       0.62349
# 5       -0.5      0.781831       0.62349
# 6       -0.5      0.781831       0.62349
# 7       -0.5      0.781831       0.62349
# 8       -0.5      0.781831       0.62349
# 9       -0.5      0.781831       0.62349

# %%
old.to_csv('./4square/processed_transformed_old.csv', index=False)

# %% [markdown]
# Here, a Single User DataSet is created for the user with ID 293.
# That is the user with the most dataset entries.

# %%
#test area

t = unprocessed.merge(ubers, on='category_name', suffixes=('', '_y'), how='left')
single_user_df = t.loc[t.user_id == 293].copy()
single_user_df.head(100)
# Out:
#        user_id                     venue               category_id  \
# 690        293  4ae8fd76f964a520e1b321e3  4bf58dd8d48988d1fd931735
# 760        293  4d5bedbb5d153704613a6ce7  4bf58dd8d48988d162941735
# 763        293  41156d00f964a520f40b1fe3  4bf58dd8d48988d1d8941735
# 766        293  4d61b919865a224bef72ba85  4bf58dd8d48988d123951735
# 1121       293  4c97edbdf419a09395806b88  4f2a25ac4b909258e854f55f
# ...        ...                       ...                       ...
# 13791      293  4e5577f445dd0a4826e6ab3e  4bf58dd8d48988d103941735
# 13793      293  4d2f5ae2940137044fa1eeda  4bf58dd8d48988d1f6931735
# 13794      293  4d2f5ae2940137044fa1eeda  4bf58dd8d48988d1f6931735
# 13798      293  4b0b68cef964a5202f3123e3  4bf58dd8d48988d1fd931735
# 14702      293  4ae8fd76f964a520e1b321e3  4bf58dd8d48988d1fd931735
#
#               category_name   latitude  longitude  time_offset  \
# 690                  Subway  40.725577 -74.004252         -240
# 760    Other Great Outdoors  40.714310 -73.949394         -240
# 763                     Bar  40.713624 -73.949710         -240
# 766              Smoke Shop  40.715951 -73.949595         -240
# 1121           Neighborhood  40.650169 -73.949575         -240
# ...                     ...        ...        ...          ...
# 13791        Home (private)  40.693212 -73.930104         -240
# 13793        General Travel  40.689003 -73.929085         -240
# 13794        General Travel  40.689003 -73.929085         -240
# 13798                Subway  40.679336 -73.930285         -240
# 14702                Subway  40.725577 -74.004252         -240
#
#                                  time     uber_category
# 690    Tue Apr 03 23:56:43 +0000 2012  Public Transport
# 760    Wed Apr 04 00:19:13 +0000 2012          Outdoors
# 763    Wed Apr 04 00:19:44 +0000 2012               Bar
# 766    Wed Apr 04 00:21:12 +0000 2012          Shopping
# 1121   Wed Apr 04 04:53:06 +0000 2012              Home
# ...                               ...               ...
# 13791  Fri Apr 13 16:18:13 +0000 2012              Home
# 13793  Fri Apr 13 16:18:55 +0000 2012  Public Transport
# 13794  Fri Apr 13 16:19:13 +0000 2012  Public Transport
# 13798  Fri Apr 13 16:20:17 +0000 2012  Public Transport
# 14702  Fri Apr 13 23:51:20 +0000 2012  Public Transport
#
# [100 rows x 9 columns]

# %% [markdown]
# Next, a dataset for locations is also processed.
# Here, a join is done on areas that will be retrieved with a library.

# %%
merged.head(10)
# Out:
#    user_id                     venue               category_id  \
# 0      470  49bbd6c0f964a520f4531fe3  4bf58dd8d48988d127951735
# 1      979  4a43c0aef964a520c6a61fe3  4bf58dd8d48988d1df941735
# 2       69  4c5cc7b485a1e21e00d35711  4bf58dd8d48988d103941735
# 3      395  4bc7086715a7ef3bef9878da  4bf58dd8d48988d104941735
# 4       87  4cf2c5321d18a143951b5cec  4bf58dd8d48988d1cb941735
# 5      484  4b5b981bf964a520900929e3  4bf58dd8d48988d118951735
# 6      642  4ab966c3f964a5203c7f20e3  4bf58dd8d48988d1e0931735
# 7      292  4d0cc47f903d37041864bf55  4bf58dd8d48988d12b951735
# 8      428  4ce1863bc4f6a35d8bd2db6c  4bf58dd8d48988d103941735
# 9      877  4be319b321d5a59352311811  4bf58dd8d48988d10a951735
#
#          category_name   latitude  longitude  time_offset  \
# 0  Arts & Crafts Store  40.719810 -74.002581         -240
# 1               Bridge  40.606800 -74.044170         -240
# 2       Home (private)  40.716162 -73.883070         -240
# 3       Medical Center  40.745164 -73.982519         -240
# 4           Food Truck  40.740104 -73.989658         -240
# 5    Food & Drink Shop  40.690427 -73.954687         -240
# 6          Coffee Shop  40.751591 -73.974121         -240
# 7          Bus Station  40.779422 -73.955341         -240
# 8       Home (private)  40.619151 -74.035888         -240
# 9                 Bank  40.619006 -73.990375         -240
#
#                        time  is_weekend  cat_id  clock_sin  clock_cos  \
# 0 2012-04-03 18:00:09+00:00       False       0  -1.000000   0.000654
# 1 2012-04-03 18:00:25+00:00       False       1  -0.999998   0.001818
# 2 2012-04-03 18:02:24+00:00       False       2  -0.999945   0.010472
# 3 2012-04-03 18:02:41+00:00       False       3  -0.999931   0.011708
# 4 2012-04-03 18:03:00+00:00       False       4  -0.999914   0.013090
#  (40.765168939069156, -73.98327469825746),
#  (40.75789135498701, -73.92001066279377),
#  (40.887296786638714, -73.90658830179063),
#  (40.765363961249754, -73.97578597068788),
#  (40.951057104379366, -74.08986568450928),
#  (40.951057104379366, -74.08986568450928),
#  (40.950295402475035, -74.0872049331665),
#  (40.788546681483396, -73.97696812777984),
#  (40.724534408923176, -73.99054689365978),
#  (40.72259324307306, -74.00079633163301),
#  (40.73412061435751, -74.16445255279541),
#  (40.78577311803029, -73.9509916305542),
#  (40.73420076077984, -74.16483829470191),
#  (40.78158643369461, -74.03603390827418),
#  (40.7322039185255, -74.06293539489386),
#  (40.597704131964136, -74.16509908485864),
#  (40.742965008670524, -73.97416157683648),
#  (40.71490463023791, -74.00597249110558),
#  (40.704773805463454, -73.94186034276925),
#  (40.725354552818544, -73.99751955524732),
#  (40.76062396359529, -73.98530718776547),
#  (40.73287356825004, -73.9975941550718),
#  (40.732267009830224, -74.06304359436034),
#  (40.74211978889589, -73.82529258728026),
#  (40.763787515573, -73.99750113487244),
#  (40.75850533742767, -73.98914337158203),
#  (40.741209362255695, -73.98768424987794),
#  (40.704773805463454, -73.94186034276925),
#  (40.860352891422785, -74.19816255569458),
#  (40.721613003878296, -73.95814221792891),
#  (40.83784887414401, -73.94397565768429),
#  (40.737271, -73.996622),
#  (40.73929092246981, -74.15574073791505),
#  (40.70706694230483, -73.95194304057539),
#  (40.707018051070186, -73.95018657082707),
#  (40.7107667, -73.95655),
#  (40.70956429635586, -73.79806280136107),
#  (40.74219429627965, -73.78896894871082),
#  (40.735687799616535, -73.81273680526725),
#  (40.721215, -73.98739300000001),
#  (40.85064963236761, -73.8957051503127),
#  (40.714463564285154, -73.99882797705891),
#  (40.714952200568035, -73.99824837025356),
#  (40.73021150171887, -74.00029133297183),
#  (40.73420076077984, -74.16483829470191),
#  (40.75976949498497, -73.96155742041212),
#  (40.62834894150094, -74.00586919882659),
#  (40.758873124332524, -73.96266519579537),
#  (40.645089355976346, -73.7845230102539),
#  (40.735604988736725, -73.9719633703152),
#  (40.644099068159, -74.09980183101945),
#  ...]

# %% [markdown]
# Now, the reverse_geocoder library is used to lookup all coordinates.

# %%
coord_array = [(i[1], i[0]) for i in coords]
search = rg.search(coord_array)
search
# Out:
# Loading formatted geocoded file...
# [OrderedDict([('lat', '40.71427'),
#               ('lon', '-74.00597'),
#               ('name', 'New York City'),
#               ('admin1', 'New York'),
#               ('admin2', ''),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.60177'),
#               ('lon', '-73.99403'),
#               ('name', 'Bensonhurst'),
#               ('admin1', 'New York'),
#               ('admin2', 'Kings County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.66677'),
#               ('lon', '-73.88236'),
#               ('name', 'East New York'),
#               ('admin1', 'New York'),
#               ('admin2', 'Kings County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.74482'),
#               ('lon', '-73.94875'),
#               ('name', 'Long Island City'),
#               ('admin1', 'New York'),
#               ('admin2', 'Queens County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.71427'),
#               ('lon', '-74.00597'),
#               ('name', 'New York City'),
#               ('admin1', 'New York'),
#               ('admin2', ''),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.6501'),
#               ('lon', '-73.94958'),
#               ('name', 'Brooklyn'),
#               ('admin1', 'New York'),
#               ('admin2', 'Kings County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.74482'),
#               ('lon', '-73.94875'),
#               ('name', 'Long Island City'),
#               ('admin1', 'New York'),
#               ('admin2', 'Queens County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.78343'),
#               ('lon', '-73.96625'),
#               ('name', 'Manhattan'),
#               ('admin1', 'New York'),
#               ('admin2', 'New York County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.60177'),
#               ('lon', '-73.99403'),
#               ('name', 'Bensonhurst'),
#               ('admin1', 'New York'),
#               ('admin2', 'Kings County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.60177'),
#               ('lon', '-73.99403'),
#               ('name', 'Bensonhurst'),
#               ('admin1', 'New York'),
#               ('admin2', 'Kings County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.71427'),
#               ('lon', '-74.00597'),
#               ('name', 'New York City'),
#               ('admin1', 'New York'),
#               ('admin2', ''),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.71427'),
#               ('lon', '-74.00597'),
#               ('name', 'New York City'),
#               ('admin1', 'New York'),
#               ('admin2', ''),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.73232'),
#               ('lon', '-74.23487'),
#               ('name', 'Irvington'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Essex County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.71427'),
#               ('lon', '-74.00597'),
#               ('name', 'New York City'),
#               ('admin1', 'New York'),
#               ('admin2', ''),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.71427'),
#               ('lon', '-74.00597'),
#               ('name', 'New York City'),
#               ('admin1', 'New York'),
#               ('admin2', ''),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.85288'),
#               ('lon', '-74.04208'),
#               ('name', 'Little Ferry'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Bergen County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.82704'),
#               ('lon', '-73.97569'),
#               ('name', 'Edgewater'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Bergen County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.78343'),
#               ('lon', '-73.96625'),
#               ('name', 'Manhattan'),
#               ('admin1', 'New York'),
#               ('admin2', 'New York County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.91149'),
#               ('lon', '-73.78235'),
#               ('name', 'New Rochelle'),
#               ('admin1', 'New York'),
#               ('admin2', 'Westchester County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.72816'),
#               ('lon', '-74.07764'),
#               ('name', 'Jersey City'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Hudson County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.88232'),
#               ('lon', '-74.0832'),
#               ('name', 'Lodi'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Bergen County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.71427'),
#               ('lon', '-74.00597'),
#               ('name', 'New York City'),
#               ('admin1', 'New York'),
#               ('admin2', ''),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.62205'),
#               ('lon', '-73.7468'),
#               ('name', 'Inwood'),
#               ('admin1', 'New York'),
#               ('admin2', 'Nassau County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.76955'),
#               ('lon', '-74.02042'),
#               ('name', 'Weehawken'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Hudson County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.71427'),
#               ('lon', '-74.00597'),
#               ('name', 'New York City'),
#               ('admin1', 'New York'),
#               ('admin2', ''),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.78343'),
#               ('lon', '-73.96625'),
#               ('name', 'Manhattan'),
#               ('admin1', 'New York'),
#               ('admin2', 'New York County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.74482'),
#               ('lon', '-73.94875'),
#               ('name', 'Long Island City'),
#               ('admin1', 'New York'),
#               ('admin2', 'Queens County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.60177'),
#               ('lon', '-73.99403'),
#               ('name', 'Bensonhurst'),
#               ('admin1', 'New York'),
#               ('admin2', 'Kings County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.71427'),
#               ('lon', '-74.00597'),
#               ('name', 'New York City'),
#               ('admin1', 'New York'),
#               ('admin2', ''),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.76955'),
#               ('lon', '-74.02042'),
#               ('name', 'Weehawken'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Hudson County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.74482'),
#               ('lon', '-73.94875'),
#               ('name', 'Long Island City'),
#               ('admin1', 'New York'),
#               ('admin2', 'Queens County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.71427'),
#               ('lon', '-74.00597'),
#               ('name', 'New York City'),
#               ('admin1', 'New York'),
#               ('admin2', ''),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.82704'),
#               ('lon', '-73.97569'),
#               ('name', 'Edgewater'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Bergen County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.86899'),
#               ('lon', '-74.2082'),
#               ('name', 'Little Falls'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Passaic County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.71427'),
#               ('lon', '-74.00597'),
#               ('name', 'New York City'),
#               ('admin1', 'New York'),
#               ('admin2', ''),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.91677'),
#               ('lon', '-74.17181'),
#               ('name', 'Paterson'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Passaic County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.94454'),
#               ('lon', '-74.07542'),
#               ('name', 'Paramus'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Bergen County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.94454'),
#               ('lon', '-74.07542'),
#               ('name', 'Paramus'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Bergen County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.71427'),
#               ('lon', '-74.00597'),
#               ('name', 'New York City'),
#               ('admin1', 'New York'),
#               ('admin2', ''),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.71427'),
#               ('lon', '-74.00597'),
#               ('name', 'New York City'),
#               ('admin1', 'New York'),
#               ('admin2', ''),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.78343'),
#               ('lon', '-73.96625'),
#               ('name', 'Manhattan'),
#               ('admin1', 'New York'),
#               ('admin2', 'New York County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.71427'),
#               ('lon', '-74.00597'),
#               ('name', 'New York City'),
#               ('admin1', 'New York'),
#               ('admin2', ''),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.78343'),
#               ('lon', '-73.96625'),
#               ('name', 'Manhattan'),
#               ('admin1', 'New York'),
#               ('admin2', 'New York County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.78982'),
#               ('lon', '-73.74708'),
#               ('name', 'East Atlantic Beach'),
#               ('admin1', 'New York'),
#               ('admin2', 'Nassau County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.76955'),
#               ('lon', '-74.02042'),
#               ('name', 'Weehawken'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Hudson County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.71427'),
#               ('lon', '-74.00597'),
#               ('name', 'New York City'),
#               ('admin1', 'New York'),
#               ('admin2', ''),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.71427'),
#               ('lon', '-74.00597'),
#               ('name', 'New York City'),
#               ('admin1', 'New York'),
#               ('admin2', ''),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.78343'),
#               ('lon', '-73.96625'),
#               ('name', 'Manhattan'),
#               ('admin1', 'New York'),
#               ('admin2', 'New York County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.9276'),
#               ('lon', '-73.99736'),
#               ('name', 'Bergenfield'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Bergen County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.78343'),
#               ('lon', '-73.96625'),
#               ('name', 'Manhattan'),
#               ('admin1', 'New York'),
#               ('admin2', 'New York County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.80677'),
#               ('lon', '-74.18542'),
#               ('name', 'Bloomfield'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Essex County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.80677'),
#               ('lon', '-74.18542'),
#               ('name', 'Bloomfield'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Essex County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.88149'),
#               ('lon', '-74.1132'),
#               ('name', 'Garfield'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Bergen County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.82704'),
#               ('lon', '-73.97569'),
#               ('name', 'Edgewater'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Bergen County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.80427'),
#               ('lon', '-74.01208'),
#               ('name', 'North Bergen'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Hudson County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.78343'),
#               ('lon', '-73.96625'),
#               ('name', 'Manhattan'),
#               ('admin1', 'New York'),
#               ('admin2', 'New York County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.79205'),
#               ('lon', '-74.00375'),
#               ('name', 'Guttenberg'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Hudson County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.71427'),
#               ('lon', '-74.00597'),
#               ('name', 'New York City'),
#               ('admin1', 'New York'),
#               ('admin2', ''),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.60177'),
#               ('lon', '-73.99403'),
#               ('name', 'Bensonhurst'),
#               ('admin1', 'New York'),
#               ('admin2', 'Kings County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.74482'),
#               ('lon', '-73.94875'),
#               ('name', 'Long Island City'),
#               ('admin1', 'New York'),
#               ('admin2', 'Queens County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.76955'),
#               ('lon', '-74.02042'),
#               ('name', 'Weehawken'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Hudson County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.76955'),
#               ('lon', '-74.02042'),
#               ('name', 'Weehawken'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Hudson County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.9351'),
#               ('lon', '-74.01903'),
#               ('name', 'New Milford'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Bergen County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.74649'),
#               ('lon', '-74.15626'),
#               ('name', 'Harrison'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Hudson County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.68149'),
#               ('lon', '-73.83652'),
#               ('name', 'Borough of Queens'),
#               ('admin1', 'New York'),
#               ('admin2', 'Queens County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.74482'),
#               ('lon', '-73.94875'),
#               ('name', 'Long Island City'),
#               ('admin1', 'New York'),
#               ('admin2', 'Queens County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.71427'),
#               ('lon', '-74.00597'),
#               ('name', 'New York City'),
#               ('admin1', 'New York'),
#               ('admin2', ''),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.73566'),
#               ('lon', '-74.17237'),
#               ('name', 'Newark'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Essex County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.78343'),
#               ('lon', '-73.96625'),
#               ('name', 'Manhattan'),
#               ('admin1', 'New York'),
#               ('admin2', 'New York County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.71427'),
#               ('lon', '-74.00597'),
#               ('name', 'New York City'),
#               ('admin1', 'New York'),
#               ('admin2', ''),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.71427'),
#               ('lon', '-74.00597'),
#               ('name', 'New York City'),
#               ('admin1', 'New York'),
#               ('admin2', ''),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.78343'),
#               ('lon', '-73.96625'),
#               ('name', 'Manhattan'),
#               ('admin1', 'New York'),
#               ('admin2', 'New York County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.74482'),
#               ('lon', '-73.94875'),
#               ('name', 'Long Island City'),
#               ('admin1', 'New York'),
#               ('admin2', 'Queens County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.74482'),
#               ('lon', '-73.94875'),
#               ('name', 'Long Island City'),
#               ('admin1', 'New York'),
#               ('admin2', 'Queens County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.82593'),
#               ('lon', '-74.20903'),
#               ('name', 'Montclair'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Essex County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.74399'),
#               ('lon', '-74.03236'),
#               ('name', 'Hoboken'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Hudson County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.78343'),
#               ('lon', '-73.96625'),
#               ('name', 'Manhattan'),
#               ('admin1', 'New York'),
#               ('admin2', 'New York County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.86899'),
#               ('lon', '-74.2082'),
#               ('name', 'Little Falls'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Passaic County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.74482'),
#               ('lon', '-73.94875'),
#               ('name', 'Long Island City'),
#               ('admin1', 'New York'),
#               ('admin2', 'Queens County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.71427'),
#               ('lon', '-74.00597'),
#               ('name', 'New York City'),
#               ('admin1', 'New York'),
#               ('admin2', ''),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.8976'),
#               ('lon', '-74.01597'),
#               ('name', 'Teaneck'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Bergen County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.74482'),
#               ('lon', '-73.94875'),
#               ('name', 'Long Island City'),
#               ('admin1', 'New York'),
#               ('admin2', 'Queens County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.91149'),
#               ('lon', '-73.78235'),
#               ('name', 'New Rochelle'),
#               ('admin1', 'New York'),
#               ('admin2', 'Westchester County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.69149'),
#               ('lon', '-73.80569'),
#               ('name', 'Jamaica'),
#               ('admin1', 'New York'),
#               ('admin2', 'Queens County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.78955'),
#               ('lon', '-74.05653'),
#               ('name', 'Secaucus'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Hudson County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.74399'),
#               ('lon', '-74.03236'),
#               ('name', 'Hoboken'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Hudson County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.74482'),
#               ('lon', '-73.94875'),
#               ('name', 'Long Island City'),
#               ('admin1', 'New York'),
#               ('admin2', 'Queens County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.74482'),
#               ('lon', '-73.94875'),
#               ('name', 'Long Island City'),
#               ('admin1', 'New York'),
#               ('admin2', 'Queens County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.73566'),
#               ('lon', '-74.17237'),
#               ('name', 'Newark'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Essex County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.69149'),
#               ('lon', '-73.80569'),
#               ('name', 'Jamaica'),
#               ('admin1', 'New York'),
#               ('admin2', 'Queens County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.81204'),
#               ('lon', '-74.12431'),
#               ('name', 'Lyndhurst'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Bergen County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.69149'),
#               ('lon', '-73.80569'),
#               ('name', 'Jamaica'),
#               ('admin1', 'New York'),
#               ('admin2', 'Queens County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.74399'),
#               ('lon', '-74.03236'),
#               ('name', 'Hoboken'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Hudson County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.78343'),
#               ('lon', '-73.96625'),
#               ('name', 'Manhattan'),
#               ('admin1', 'New York'),
#               ('admin2', 'New York County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.78343'),
#               ('lon', '-73.96625'),
#               ('name', 'Manhattan'),
#               ('admin1', 'New York'),
#               ('admin2', 'New York County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.84985'),
#               ('lon', '-73.86641'),
#               ('name', 'The Bronx'),
#               ('admin1', 'New York'),
#               ('admin2', 'Bronx'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.71427'),
#               ('lon', '-74.00597'),
#               ('name', 'New York City'),
#               ('admin1', 'New York'),
#               ('admin2', ''),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.60177'),
#               ('lon', '-73.99403'),
#               ('name', 'Bensonhurst'),
#               ('admin1', 'New York'),
#               ('admin2', 'Kings County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.88149'),
#               ('lon', '-74.1132'),
#               ('name', 'Garfield'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Bergen County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.82704'),
#               ('lon', '-73.97569'),
#               ('name', 'Edgewater'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Bergen County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.74482'),
#               ('lon', '-73.94875'),
#               ('name', 'Long Island City'),
#               ('admin1', 'New York'),
#               ('admin2', 'Queens County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.65594'),
#               ('lon', '-73.71763'),
#               ('name', 'South Valley Stream'),
#               ('admin1', 'New York'),
#               ('admin2', 'Nassau County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.65594'),
#               ('lon', '-73.71763'),
#               ('name', 'South Valley Stream'),
#               ('admin1', 'New York'),
#               ('admin2', 'Nassau County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.74482'),
#               ('lon', '-73.94875'),
#               ('name', 'Long Island City'),
#               ('admin1', 'New York'),
#               ('admin2', 'Queens County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.62205'),
#               ('lon', '-73.7468'),
#               ('name', 'Inwood'),
#               ('admin1', 'New York'),
#               ('admin2', 'Nassau County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.71427'),
#               ('lon', '-74.00597'),
#               ('name', 'New York City'),
#               ('admin1', 'New York'),
#               ('admin2', ''),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.69149'),
#               ('lon', '-73.80569'),
#               ('name', 'Jamaica'),
#               ('admin1', 'New York'),
#               ('admin2', 'Queens County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.69149'),
#               ('lon', '-73.80569'),
#               ('name', 'Jamaica'),
#               ('admin1', 'New York'),
#               ('admin2', 'Queens County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.74482'),
#               ('lon', '-73.94875'),
#               ('name', 'Long Island City'),
#               ('admin1', 'New York'),
#               ('admin2', 'Queens County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.78343'),
#               ('lon', '-73.96625'),
#               ('name', 'Manhattan'),
#               ('admin1', 'New York'),
#               ('admin2', 'New York County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.71427'),
#               ('lon', '-74.00597'),
#               ('name', 'New York City'),
#               ('admin1', 'New York'),
#               ('admin2', ''),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.71427'),
#               ('lon', '-74.00597'),
#               ('name', 'New York City'),
#               ('admin1', 'New York'),
#               ('admin2', ''),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.78343'),
#               ('lon', '-73.96625'),
#               ('name', 'Manhattan'),
#               ('admin1', 'New York'),
#               ('admin2', 'New York County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.71427'),
#               ('lon', '-74.00597'),
#               ('name', 'New York City'),
#               ('admin1', 'New York'),
#               ('admin2', ''),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.82593'),
#               ('lon', '-74.20903'),
#               ('name', 'Montclair'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Essex County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.78343'),
#               ('lon', '-73.96625'),
#               ('name', 'Manhattan'),
#               ('admin1', 'New York'),
#               ('admin2', 'New York County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.84985'),
#               ('lon', '-73.86641'),
#               ('name', 'The Bronx'),
#               ('admin1', 'New York'),
#               ('admin2', 'Bronx'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.74482'),
#               ('lon', '-73.94875'),
#               ('name', 'Long Island City'),
#               ('admin1', 'New York'),
#               ('admin2', 'Queens County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.57788'),
#               ('lon', '-73.99403'),
#               ('name', 'Coney Island'),
#               ('admin1', 'New York'),
#               ('admin2', 'Kings County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.74482'),
#               ('lon', '-73.94875'),
#               ('name', 'Long Island City'),
#               ('admin1', 'New York'),
#               ('admin2', 'Queens County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.9351'),
#               ('lon', '-74.01903'),
#               ('name', 'New Milford'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Bergen County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.62205'),
#               ('lon', '-73.7468'),
#               ('name', 'Inwood'),
#               ('admin1', 'New York'),
#               ('admin2', 'Nassau County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.94149'),
#               ('lon', '-73.9593'),
#               ('name', 'Cresskill'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Bergen County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.71427'),
#               ('lon', '-74.00597'),
#               ('name', 'New York City'),
#               ('admin1', 'New York'),
#               ('admin2', ''),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.84121'),
#               ('lon', '-74.04514'),
#               ('name', 'Moonachie'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Bergen County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.71427'),
#               ('lon', '-74.00597'),
#               ('name', 'New York City'),
#               ('admin1', 'New York'),
#               ('admin2', ''),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.84121'),
#               ('lon', '-74.04514'),
#               ('name', 'Moonachie'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Bergen County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.78343'),
#               ('lon', '-73.96625'),
#               ('name', 'Manhattan'),
#               ('admin1', 'New York'),
#               ('admin2', 'New York County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.71427'),
#               ('lon', '-74.00597'),
#               ('name', 'New York City'),
#               ('admin1', 'New York'),
#               ('admin2', ''),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.89899'),
#               ('lon', '-74.09264'),
#               ('name', 'Saddle Brook'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Bergen County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.71427'),
#               ('lon', '-74.00597'),
#               ('name', 'New York City'),
#               ('admin1', 'New York'),
#               ('admin2', ''),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.78955'),
#               ('lon', '-74.05653'),
#               ('name', 'Secaucus'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Hudson County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.78955'),
#               ('lon', '-74.05653'),
#               ('name', 'Secaucus'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Hudson County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.74482'),
#               ('lon', '-73.94875'),
#               ('name', 'Long Island City'),
#               ('admin1', 'New York'),
#               ('admin2', 'Queens County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.78343'),
#               ('lon', '-73.96625'),
#               ('name', 'Manhattan'),
#               ('admin1', 'New York'),
#               ('admin2', 'New York County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.69149'),
#               ('lon', '-73.80569'),
#               ('name', 'Jamaica'),
#               ('admin1', 'New York'),
#               ('admin2', 'Queens County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.66399'),
#               ('lon', '-74.2107'),
#               ('name', 'Elizabeth'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Union County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.66677'),
#               ('lon', '-73.88236'),
#               ('name', 'East New York'),
#               ('admin1', 'New York'),
#               ('admin2', 'Kings County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.71427'),
#               ('lon', '-74.00597'),
#               ('name', 'New York City'),
#               ('admin1', 'New York'),
#               ('admin2', ''),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.78343'),
#               ('lon', '-73.96625'),
#               ('name', 'Manhattan'),
#               ('admin1', 'New York'),
#               ('admin2', 'New York County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.71427'),
#               ('lon', '-74.00597'),
#               ('name', 'New York City'),
#               ('admin1', 'New York'),
#               ('admin2', ''),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.76955'),
#               ('lon', '-74.02042'),
#               ('name', 'Weehawken'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Hudson County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.71427'),
#               ('lon', '-74.00597'),
#               ('name', 'New York City'),
#               ('admin1', 'New York'),
#               ('admin2', ''),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.60177'),
#               ('lon', '-73.99403'),
#               ('name', 'Bensonhurst'),
#               ('admin1', 'New York'),
#               ('admin2', 'Kings County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.71427'),
#               ('lon', '-74.00597'),
#               ('name', 'New York City'),
#               ('admin1', 'New York'),
#               ('admin2', ''),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.71427'),
#               ('lon', '-74.00597'),
#               ('name', 'New York City'),
#               ('admin1', 'New York'),
#               ('admin2', ''),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.71427'),
#               ('lon', '-74.00597'),
#               ('name', 'New York City'),
#               ('admin1', 'New York'),
#               ('admin2', ''),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.68149'),
#               ('lon', '-73.83652'),
#               ('name', 'Borough of Queens'),
#               ('admin1', 'New York'),
#               ('admin2', 'Queens County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.94454'),
#               ('lon', '-74.07542'),
#               ('name', 'Paramus'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Bergen County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.69149'),
#               ('lon', '-73.80569'),
#               ('name', 'Jamaica'),
#               ('admin1', 'New York'),
#               ('admin2', 'Queens County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.85843'),
#               ('lon', '-74.16376'),
#               ('name', 'Clifton'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Passaic County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.71427'),
#               ('lon', '-74.00597'),
#               ('name', 'New York City'),
#               ('admin1', 'New York'),
#               ('admin2', ''),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.71427'),
#               ('lon', '-74.00597'),
#               ('name', 'New York City'),
#               ('admin1', 'New York'),
#               ('admin2', ''),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.93121'),
#               ('lon', '-73.89875'),
#               ('name', 'Yonkers'),
#               ('admin1', 'New York'),
#               ('admin2', 'Westchester County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.71427'),
#               ('lon', '-74.00597'),
#               ('name', 'New York City'),
#               ('admin1', 'New York'),
#               ('admin2', ''),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.60177'),
#               ('lon', '-73.99403'),
#               ('name', 'Bensonhurst'),
#               ('admin1', 'New York'),
#               ('admin2', 'Kings County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.77955'),
#               ('lon', '-74.02375'),
#               ('name', 'Union City'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Hudson County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.70094'),
#               ('lon', '-73.71291'),
#               ('name', 'Elmont'),
#               ('admin1', 'New York'),
#               ('admin2', 'Nassau County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.71427'),
#               ('lon', '-74.00597'),
#               ('name', 'New York City'),
#               ('admin1', 'New York'),
#               ('admin2', ''),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.74649'),
#               ('lon', '-74.15626'),
#               ('name', 'Harrison'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Hudson County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.80538'),
#               ('lon', '-74.20376'),
#               ('name', 'Glen Ridge'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Essex County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.82704'),
#               ('lon', '-73.97569'),
#               ('name', 'Edgewater'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Bergen County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.76955'),
#               ('lon', '-74.02042'),
#               ('name', 'Weehawken'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Hudson County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.74482'),
#               ('lon', '-73.94875'),
#               ('name', 'Long Island City'),
#               ('admin1', 'New York'),
#               ('admin2', 'Queens County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.74482'),
#               ('lon', '-73.94875'),
#               ('name', 'Long Island City'),
#               ('admin1', 'New York'),
#               ('admin2', 'Queens County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.71427'),
#               ('lon', '-74.00597'),
#               ('name', 'New York City'),
#               ('admin1', 'New York'),
#               ('admin2', ''),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.78343'),
#               ('lon', '-73.96625'),
#               ('name', 'Manhattan'),
#               ('admin1', 'New York'),
#               ('admin2', 'New York County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.78343'),
#               ('lon', '-73.96625'),
#               ('name', 'Manhattan'),
#               ('admin1', 'New York'),
#               ('admin2', 'New York County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.74482'),
#               ('lon', '-73.94875'),
#               ('name', 'Long Island City'),
#               ('admin1', 'New York'),
#               ('admin2', 'Queens County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.6501'),
#               ('lon', '-73.94958'),
#               ('name', 'Brooklyn'),
#               ('admin1', 'New York'),
#               ('admin2', 'Kings County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.66677'),
#               ('lon', '-73.88236'),
#               ('name', 'East New York'),
#               ('admin1', 'New York'),
#               ('admin2', 'Kings County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.78343'),
#               ('lon', '-73.96625'),
#               ('name', 'Manhattan'),
#               ('admin1', 'New York'),
#               ('admin2', 'New York County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.84985'),
#               ('lon', '-73.86641'),
#               ('name', 'The Bronx'),
#               ('admin1', 'New York'),
#               ('admin2', 'Bronx'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.81204'),
#               ('lon', '-74.12431'),
#               ('name', 'Lyndhurst'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Bergen County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.62205'),
#               ('lon', '-73.7468'),
#               ('name', 'Inwood'),
#               ('admin1', 'New York'),
#               ('admin2', 'Nassau County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.78343'),
#               ('lon', '-73.96625'),
#               ('name', 'Manhattan'),
#               ('admin1', 'New York'),
#               ('admin2', 'New York County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.71427'),
#               ('lon', '-74.00597'),
#               ('name', 'New York City'),
#               ('admin1', 'New York'),
#               ('admin2', ''),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.84985'),
#               ('lon', '-73.86641'),
#               ('name', 'The Bronx'),
#               ('admin1', 'New York'),
#               ('admin2', 'Bronx'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.71427'),
#               ('lon', '-74.00597'),
#               ('name', 'New York City'),
#               ('admin1', 'New York'),
#               ('admin2', ''),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.82982'),
#               ('lon', '-74.24015'),
#               ('name', 'Verona'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Essex County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.93815'),
#               ('lon', '-73.83208'),
#               ('name', 'Bronxville'),
#               ('admin1', 'New York'),
#               ('admin2', 'Westchester County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.69149'),
#               ('lon', '-73.80569'),
#               ('name', 'Jamaica'),
#               ('admin1', 'New York'),
#               ('admin2', 'Queens County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.86566'),
#               ('lon', '-73.9268'),
#               ('name', 'Inwood'),
#               ('admin1', 'New York'),
#               ('admin2', 'New York County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.74482'),
#               ('lon', '-73.94875'),
#               ('name', 'Long Island City'),
#               ('admin1', 'New York'),
#               ('admin2', 'Queens County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.74482'),
#               ('lon', '-73.94875'),
#               ('name', 'Long Island City'),
#               ('admin1', 'New York'),
#               ('admin2', 'Queens County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.71427'),
#               ('lon', '-74.00597'),
#               ('name', 'New York City'),
#               ('admin1', 'New York'),
#               ('admin2', ''),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.71427'),
#               ('lon', '-74.00597'),
#               ('name', 'New York City'),
#               ('admin1', 'New York'),
#               ('admin2', ''),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.74482'),
#               ('lon', '-73.94875'),
#               ('name', 'Long Island City'),
#               ('admin1', 'New York'),
#               ('admin2', 'Queens County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.71427'),
#               ('lon', '-74.00597'),
#               ('name', 'New York City'),
#               ('admin1', 'New York'),
#               ('admin2', ''),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.84985'),
#               ('lon', '-73.86641'),
#               ('name', 'The Bronx'),
#               ('admin1', 'New York'),
#               ('admin2', 'Bronx'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.94454'),
#               ('lon', '-74.07542'),
#               ('name', 'Paramus'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Bergen County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.76955'),
#               ('lon', '-74.02042'),
#               ('name', 'Weehawken'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Hudson County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.74482'),
#               ('lon', '-73.94875'),
#               ('name', 'Long Island City'),
#               ('admin1', 'New York'),
#               ('admin2', 'Queens County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.8126'),
#               ('lon', '-73.99903'),
#               ('name', 'Fairview'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Bergen County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.71427'),
#               ('lon', '-74.00597'),
#               ('name', 'New York City'),
#               ('admin1', 'New York'),
#               ('admin2', ''),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.71427'),
#               ('lon', '-74.00597'),
#               ('name', 'New York City'),
#               ('admin1', 'New York'),
#               ('admin2', ''),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.71427'),
#               ('lon', '-74.00597'),
#               ('name', 'New York City'),
#               ('admin1', 'New York'),
#               ('admin2', ''),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.8876'),
#               ('lon', '-73.83291'),
#               ('name', 'Eastchester'),
#               ('admin1', 'New York'),
#               ('admin2', 'Bronx'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.74482'),
#               ('lon', '-73.94875'),
#               ('name', 'Long Island City'),
#               ('admin1', 'New York'),
#               ('admin2', 'Queens County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.8876'),
#               ('lon', '-73.83291'),
#               ('name', 'Eastchester'),
#               ('admin1', 'New York'),
#               ('admin2', 'Bronx'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.78343'),
#               ('lon', '-73.96625'),
#               ('name', 'Manhattan'),
#               ('admin1', 'New York'),
#               ('admin2', 'New York County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.71427'),
#               ('lon', '-74.00597'),
#               ('name', 'New York City'),
#               ('admin1', 'New York'),
#               ('admin2', ''),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.8876'),
#               ('lon', '-73.83291'),
#               ('name', 'Eastchester'),
#               ('admin1', 'New York'),
#               ('admin2', 'Bronx'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.71427'),
#               ('lon', '-74.00597'),
#               ('name', 'New York City'),
#               ('admin1', 'New York'),
#               ('admin2', ''),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.60177'),
#               ('lon', '-73.99403'),
#               ('name', 'Bensonhurst'),
#               ('admin1', 'New York'),
#               ('admin2', 'Kings County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.74399'),
#               ('lon', '-74.03236'),
#               ('name', 'Hoboken'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Hudson County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.74399'),
#               ('lon', '-74.03236'),
#               ('name', 'Hoboken'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Hudson County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.71427'),
#               ('lon', '-74.00597'),
#               ('name', 'New York City'),
#               ('admin1', 'New York'),
#               ('admin2', ''),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.76955'),
#               ('lon', '-74.02042'),
#               ('name', 'Weehawken'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Hudson County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.74649'),
#               ('lon', '-74.15626'),
#               ('name', 'Harrison'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Hudson County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.71427'),
#               ('lon', '-74.00597'),
#               ('name', 'New York City'),
#               ('admin1', 'New York'),
#               ('admin2', ''),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.57788'),
#               ('lon', '-73.99403'),
#               ('name', 'Coney Island'),
#               ('admin1', 'New York'),
#               ('admin2', 'Kings County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.71427'),
#               ('lon', '-74.00597'),
#               ('name', 'New York City'),
#               ('admin1', 'New York'),
#               ('admin2', ''),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.71427'),
#               ('lon', '-74.00597'),
#               ('name', 'New York City'),
#               ('admin1', 'New York'),
#               ('admin2', ''),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.80538'),
#               ('lon', '-74.20376'),
#               ('name', 'Glen Ridge'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Essex County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.78343'),
#               ('lon', '-73.96625'),
#               ('name', 'Manhattan'),
#               ('admin1', 'New York'),
#               ('admin2', 'New York County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.74482'),
#               ('lon', '-73.94875'),
#               ('name', 'Long Island City'),
#               ('admin1', 'New York'),
#               ('admin2', 'Queens County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.78343'),
#               ('lon', '-73.96625'),
#               ('name', 'Manhattan'),
#               ('admin1', 'New York'),
#               ('admin2', 'New York County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.71427'),
#               ('lon', '-74.00597'),
#               ('name', 'New York City'),
#               ('admin1', 'New York'),
#               ('admin2', ''),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.71427'),
#               ('lon', '-74.00597'),
#               ('name', 'New York City'),
#               ('admin1', 'New York'),
#               ('admin2', ''),
# ...
#  OrderedDict([('lat', '40.74482'),
#               ('lon', '-73.94875'),
#               ('name', 'Long Island City'),
#               ('admin1', 'New York'),
#               ('admin2', 'Queens County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.74399'),
#               ('lon', '-74.03236'),
#               ('name', 'Hoboken'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Hudson County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.78343'),
#               ('lon', '-73.96625'),
#               ('name', 'Manhattan'),
#               ('admin1', 'New York'),
#               ('admin2', 'New York County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.72816'),
#               ('lon', '-74.07764'),
#               ('name', 'Jersey City'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Hudson County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.71427'),
#               ('lon', '-74.00597'),
#               ('name', 'New York City'),
#               ('admin1', 'New York'),
#               ('admin2', ''),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.78343'),
#               ('lon', '-73.96625'),
#               ('name', 'Manhattan'),
#               ('admin1', 'New York'),
#               ('admin2', 'New York County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.74482'),
#               ('lon', '-73.94875'),
#               ('name', 'Long Island City'),
#               ('admin1', 'New York'),
#               ('admin2', 'Queens County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.82649'),
#               ('lon', '-74.10681'),
#               ('name', 'Rutherford'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Bergen County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.6501'),
#               ('lon', '-73.94958'),
#               ('name', 'Brooklyn'),
#               ('admin1', 'New York'),
#               ('admin2', 'Kings County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.71427'),
#               ('lon', '-74.00597'),
#               ('name', 'New York City'),
#               ('admin1', 'New York'),
#               ('admin2', ''),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.94454'),
#               ('lon', '-74.07542'),
#               ('name', 'Paramus'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Bergen County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.86566'),
#               ('lon', '-73.9268'),
#               ('name', 'Inwood'),
#               ('admin1', 'New York'),
#               ('admin2', 'New York County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.74482'),
#               ('lon', '-73.94875'),
#               ('name', 'Long Island City'),
#               ('admin1', 'New York'),
#               ('admin2', 'Queens County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.71427'),
#               ('lon', '-74.00597'),
#               ('name', 'New York City'),
#               ('admin1', 'New York'),
#               ('admin2', ''),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.71427'),
#               ('lon', '-74.00597'),
#               ('name', 'New York City'),
#               ('admin1', 'New York'),
#               ('admin2', ''),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.66677'),
#               ('lon', '-73.88236'),
#               ('name', 'East New York'),
#               ('admin1', 'New York'),
#               ('admin2', 'Kings County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.76955'),
#               ('lon', '-74.02042'),
#               ('name', 'Weehawken'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Hudson County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.78343'),
#               ('lon', '-73.96625'),
#               ('name', 'Manhattan'),
#               ('admin1', 'New York'),
#               ('admin2', 'New York County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.74482'),
#               ('lon', '-73.94875'),
#               ('name', 'Long Island City'),
#               ('admin1', 'New York'),
#               ('admin2', 'Queens County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.78343'),
#               ('lon', '-73.96625'),
#               ('name', 'Manhattan'),
#               ('admin1', 'New York'),
#               ('admin2', 'New York County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.74482'),
#               ('lon', '-73.94875'),
#               ('name', 'Long Island City'),
#               ('admin1', 'New York'),
#               ('admin2', 'Queens County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.78343'),
#               ('lon', '-73.96625'),
#               ('name', 'Manhattan'),
#               ('admin1', 'New York'),
#               ('admin2', 'New York County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.78343'),
#               ('lon', '-73.96625'),
#               ('name', 'Manhattan'),
#               ('admin1', 'New York'),
#               ('admin2', 'New York County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.74482'),
#               ('lon', '-73.94875'),
#               ('name', 'Long Island City'),
#               ('admin1', 'New York'),
#               ('admin2', 'Queens County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.86566'),
#               ('lon', '-73.9268'),
#               ('name', 'Inwood'),
#               ('admin1', 'New York'),
#               ('admin2', 'New York County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.78343'),
#               ('lon', '-73.96625'),
#               ('name', 'Manhattan'),
#               ('admin1', 'New York'),
#               ('admin2', 'New York County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.94454'),
#               ('lon', '-74.07542'),
#               ('name', 'Paramus'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Bergen County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.94454'),
#               ('lon', '-74.07542'),
#               ('name', 'Paramus'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Bergen County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.94454'),
#               ('lon', '-74.07542'),
#               ('name', 'Paramus'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Bergen County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.78343'),
#               ('lon', '-73.96625'),
#               ('name', 'Manhattan'),
#               ('admin1', 'New York'),
#               ('admin2', 'New York County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.71427'),
#               ('lon', '-74.00597'),
#               ('name', 'New York City'),
#               ('admin1', 'New York'),
#               ('admin2', ''),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.71427'),
#               ('lon', '-74.00597'),
#               ('name', 'New York City'),
#               ('admin1', 'New York'),
#               ('admin2', ''),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.73566'),
#               ('lon', '-74.17237'),
#               ('name', 'Newark'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Essex County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.78343'),
#               ('lon', '-73.96625'),
#               ('name', 'Manhattan'),
#               ('admin1', 'New York'),
#               ('admin2', 'New York County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.73566'),
#               ('lon', '-74.17237'),
#               ('name', 'Newark'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Essex County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.77955'),
#               ('lon', '-74.02375'),
#               ('name', 'Union City'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Hudson County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.72816'),
#               ('lon', '-74.07764'),
#               ('name', 'Jersey City'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Hudson County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.6126'),
#               ('lon', '-74.1782'),
#               ('name', 'Bloomfield'),
#               ('admin1', 'New York'),
#               ('admin2', 'Richmond County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.74482'),
#               ('lon', '-73.94875'),
#               ('name', 'Long Island City'),
#               ('admin1', 'New York'),
#               ('admin2', 'Queens County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.71427'),
#               ('lon', '-74.00597'),
#               ('name', 'New York City'),
#               ('admin1', 'New York'),
#               ('admin2', ''),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.74482'),
#               ('lon', '-73.94875'),
#               ('name', 'Long Island City'),
#               ('admin1', 'New York'),
#               ('admin2', 'Queens County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.71427'),
#               ('lon', '-74.00597'),
#               ('name', 'New York City'),
#               ('admin1', 'New York'),
#               ('admin2', ''),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.78343'),
#               ('lon', '-73.96625'),
#               ('name', 'Manhattan'),
#               ('admin1', 'New York'),
#               ('admin2', 'New York County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.71427'),
#               ('lon', '-74.00597'),
#               ('name', 'New York City'),
#               ('admin1', 'New York'),
#               ('admin2', ''),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.72816'),
#               ('lon', '-74.07764'),
#               ('name', 'Jersey City'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Hudson County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.69149'),
#               ('lon', '-73.80569'),
#               ('name', 'Jamaica'),
#               ('admin1', 'New York'),
#               ('admin2', 'Queens County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.76955'),
#               ('lon', '-74.02042'),
#               ('name', 'Weehawken'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Hudson County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.76955'),
#               ('lon', '-74.02042'),
#               ('name', 'Weehawken'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Hudson County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.71427'),
#               ('lon', '-74.00597'),
#               ('name', 'New York City'),
#               ('admin1', 'New York'),
#               ('admin2', ''),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.74482'),
#               ('lon', '-73.94875'),
#               ('name', 'Long Island City'),
#               ('admin1', 'New York'),
#               ('admin2', 'Queens County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.86899'),
#               ('lon', '-74.2082'),
#               ('name', 'Little Falls'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Passaic County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.74482'),
#               ('lon', '-73.94875'),
#               ('name', 'Long Island City'),
#               ('admin1', 'New York'),
#               ('admin2', 'Queens County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.85093'),
#               ('lon', '-73.97014'),
#               ('name', 'Fort Lee'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Bergen County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.71427'),
#               ('lon', '-74.00597'),
#               ('name', 'New York City'),
#               ('admin1', 'New York'),
#               ('admin2', ''),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.74649'),
#               ('lon', '-74.15626'),
#               ('name', 'Harrison'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Hudson County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.74482'),
#               ('lon', '-73.94875'),
#               ('name', 'Long Island City'),
#               ('admin1', 'New York'),
#               ('admin2', 'Queens County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.74482'),
#               ('lon', '-73.94875'),
#               ('name', 'Long Island City'),
#               ('admin1', 'New York'),
#               ('admin2', 'Queens County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.74482'),
#               ('lon', '-73.94875'),
#               ('name', 'Long Island City'),
#               ('admin1', 'New York'),
#               ('admin2', 'Queens County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.69149'),
#               ('lon', '-73.80569'),
#               ('name', 'Jamaica'),
#               ('admin1', 'New York'),
#               ('admin2', 'Queens County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.69149'),
#               ('lon', '-73.80569'),
#               ('name', 'Jamaica'),
#               ('admin1', 'New York'),
#               ('admin2', 'Queens County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.69149'),
#               ('lon', '-73.80569'),
#               ('name', 'Jamaica'),
#               ('admin1', 'New York'),
#               ('admin2', 'Queens County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.71427'),
#               ('lon', '-74.00597'),
#               ('name', 'New York City'),
#               ('admin1', 'New York'),
#               ('admin2', ''),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.84985'),
#               ('lon', '-73.86641'),
#               ('name', 'The Bronx'),
#               ('admin1', 'New York'),
#               ('admin2', 'Bronx'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.71427'),
#               ('lon', '-74.00597'),
#               ('name', 'New York City'),
#               ('admin1', 'New York'),
#               ('admin2', ''),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.71427'),
#               ('lon', '-74.00597'),
#               ('name', 'New York City'),
#               ('admin1', 'New York'),
#               ('admin2', ''),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.71427'),
#               ('lon', '-74.00597'),
#               ('name', 'New York City'),
#               ('admin1', 'New York'),
#               ('admin2', ''),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.73566'),
#               ('lon', '-74.17237'),
#               ('name', 'Newark'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Essex County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.74482'),
#               ('lon', '-73.94875'),
#               ('name', 'Long Island City'),
#               ('admin1', 'New York'),
#               ('admin2', 'Queens County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.60177'),
#               ('lon', '-73.99403'),
#               ('name', 'Bensonhurst'),
#               ('admin1', 'New York'),
#               ('admin2', 'Kings County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.74482'),
#               ('lon', '-73.94875'),
#               ('name', 'Long Island City'),
#               ('admin1', 'New York'),
#               ('admin2', 'Queens County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.62205'),
#               ('lon', '-73.7468'),
#               ('name', 'Inwood'),
#               ('admin1', 'New York'),
#               ('admin2', 'Nassau County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.74482'),
#               ('lon', '-73.94875'),
#               ('name', 'Long Island City'),
#               ('admin1', 'New York'),
#               ('admin2', 'Queens County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '40.66871'),
#               ('lon', '-74.11431'),
#               ('name', 'Bayonne'),
#               ('admin1', 'New Jersey'),
#               ('admin2', 'Hudson County'),
#               ('cc', 'US')]),
#  ...]

# %% [markdown]
# The results are saved in a dataframe. The columns are lat, lon, name, admin1, admin2 and cc.

# %%
values= []
for i in range(len(search)):
    values.append(search[i])

coord_search_df = pd.DataFrame(values)
coord_search_df
# Out:
#              lat        lon              name      admin1         admin2  cc
# 0       40.71427  -74.00597     New York City    New York                 US
# 1       40.60177  -73.99403       Bensonhurst    New York   Kings County  US
# 2       40.66677  -73.88236     East New York    New York   Kings County  US
# 3       40.74482  -73.94875  Long Island City    New York  Queens County  US
# 4       40.71427  -74.00597     New York City    New York                 US
# ...          ...        ...               ...         ...            ...  ..
# 227423  40.71427  -74.00597     New York City    New York                 US
# 227424  40.71427  -74.00597     New York City    New York                 US
# 227425  40.84985  -73.86641         The Bronx    New York          Bronx  US
# 227426  40.74399  -74.03236           Hoboken  New Jersey  Hudson County  US
# 227427  40.74482  -73.94875  Long Island City    New York  Queens County  US
#
# [227428 rows x 6 columns]

# %% [markdown]
# The unique values for name, admin1 and admin2 are relevant to decide which column to use for the areas.

# %%
print("Name : ", coord_search_df.name.nunique())
print("Admin1 : ", coord_search_df.admin1.nunique())
print("Admin2 : ", coord_search_df.admin2.nunique())
# Out:
# Name :  141
# Admin1 :  2
# Admin2 :  13

# %%
coord_search_df.name.value_counts()
# Out:
# New York City       49835
# Manhattan           32514
# Long Island City    28944
# Weehawken           12428
# Brooklyn            10379
#                     ...
# Plandome Heights        3
# Glen Rock               3
# Ho-Ho-Kus               1
# Plandome                1
# Larchmont               1
# Name: name, Length: 141, dtype: int64

# %% [markdown]
# The decision falls on the area name column with 141 different values. As both arrays have the same length and order, it is possible to just insert it in a column.

# %%
merged_zones = merged.copy()
merged_zones['location_name'] = coord_search_df['name']
merged_zones
# Out:
#         user_id                     venue               category_id  \
# 0           470  49bbd6c0f964a520f4531fe3  4bf58dd8d48988d127951735
# 1           979  4a43c0aef964a520c6a61fe3  4bf58dd8d48988d1df941735
# 2            69  4c5cc7b485a1e21e00d35711  4bf58dd8d48988d103941735
# 3           395  4bc7086715a7ef3bef9878da  4bf58dd8d48988d104941735
# 4            87  4cf2c5321d18a143951b5cec  4bf58dd8d48988d1cb941735
# ...         ...                       ...                       ...
# 227423      688  3fd66200f964a52000e71ee3  4bf58dd8d48988d1e7931735
# 227424      560  4bca32ff0687ef3be789dbcc  4bf58dd8d48988d16c941735
# 227425      945  50a77716e4b0b5a9492f6f56  4bf58dd8d48988d103941735
# 227426      671  4514efe0f964a520e7391fe3  4bf58dd8d48988d11d941735
# 227427      942  4a1e0ca0f964a520bf7b1fe3  4bf58dd8d48988d116941735
#
#               category_name   latitude  longitude  time_offset  \
# 0       Arts & Crafts Store  40.719810 -74.002581         -240
# 1                    Bridge  40.606800 -74.044170         -240
# 2            Home (private)  40.716162 -73.883070         -240
# 3            Medical Center  40.745164 -73.982519         -240
# 4                Food Truck  40.740104 -73.989658         -240
# ...                     ...        ...        ...          ...
# 227423          Music Venue  40.733596 -74.003139         -300
# 227424         Burger Joint  40.745719 -73.993720         -300
# 227425       Home (private)  40.854364 -73.883070         -300
# 227426                  Bar  40.735981 -74.029309         -300
# 227427                  Bar  40.726805 -73.957422         -300
#
#                             time  is_weekend  cat_id  clock_sin  clock_cos  \
# 0      2012-04-03 18:00:09+00:00       False       0  -1.000000   0.000654
# 1      2012-04-03 18:00:25+00:00       False       1  -0.999998   0.001818
# 2      2012-04-03 18:02:24+00:00       False       2  -0.999945   0.010472
# 3      2012-04-03 18:02:41+00:00       False       3  -0.999931   0.011708
# 4      2012-04-03 18:03:00+00:00       False       4  -0.999914   0.013090
# ...                          ...         ...     ...        ...        ...
# 227423 2013-02-16 02:29:11+00:00        True      16   0.605931   0.795518
# 227424 2013-02-16 02:31:35+00:00        True      11   0.614228   0.789129
# 227425 2013-02-16 02:33:16+00:00        True       2   0.620007   0.784596
# 227426 2013-02-16 02:34:31+00:00        True       9   0.624277   0.781203
# 227427 2013-02-16 02:35:36+00:00        True       9   0.627963   0.778243
#
#          day_sin   day_cos  month_sin  month_cos  week_day_sin  week_day_cos  \
# 0       0.587785  0.809017   0.866025       -0.5      0.781831      0.623490
# 1       0.587785  0.809017   0.866025       -0.5      0.781831      0.623490
# 2       0.587785  0.809017   0.866025       -0.5      0.781831      0.623490
# 3       0.587785  0.809017   0.866025       -0.5      0.781831      0.623490
# 4       0.587785  0.809017   0.866025       -0.5      0.781831      0.623490
# ...          ...       ...        ...        ...           ...           ...
# 227423 -0.207912 -0.978148   0.866025        0.5     -0.974928     -0.222521
# 227424 -0.207912 -0.978148   0.866025        0.5     -0.974928     -0.222521
# 227425 -0.207912 -0.978148   0.866025        0.5     -0.974928     -0.222521
# 227426 -0.207912 -0.978148   0.866025        0.5     -0.974928     -0.222521
# 227427 -0.207912 -0.978148   0.866025        0.5     -0.974928     -0.222521
#
#            location_name
# 0          New York City
# 1            Bensonhurst
# 2          East New York
# 3       Long Island City
# 4          New York City
# ...                  ...
# 227423     New York City
# 227424     New York City
# 227425         The Bronx
# 227426           Hoboken
# 227427  Long Island City
#
# [227428 rows x 19 columns]

# %% [markdown]
# Execute a group by on the locations to obtain ids.

# %%
merged_zones['location_id'] = merged_zones.groupby('location_name', sort=False).ngroup()

# %% [markdown]
# Move the location_id to the first column and drop not needed columns for this use case.

# %%
move_first(merged_zones, 'location_id')
merged_zones
# Out:
#         location_id  user_id                     venue  \
# 0                 0      470  49bbd6c0f964a520f4531fe3
# 1                 1      979  4a43c0aef964a520c6a61fe3
# 2                 2       69  4c5cc7b485a1e21e00d35711
# 3                 3      395  4bc7086715a7ef3bef9878da
# 4                 0       87  4cf2c5321d18a143951b5cec
# ...             ...      ...                       ...
# 227423            0      688  3fd66200f964a52000e71ee3
# 227424            0      560  4bca32ff0687ef3be789dbcc
# 227425           33      945  50a77716e4b0b5a9492f6f56
# 227426           28      671  4514efe0f964a520e7391fe3
# 227427            3      942  4a1e0ca0f964a520bf7b1fe3
#
#                      category_id        category_name   latitude  longitude  \
# 0       4bf58dd8d48988d127951735  Arts & Crafts Store  40.719810 -74.002581
# 1       4bf58dd8d48988d1df941735               Bridge  40.606800 -74.044170
# 2       4bf58dd8d48988d103941735       Home (private)  40.716162 -73.883070
# 3       4bf58dd8d48988d104941735       Medical Center  40.745164 -73.982519
# 4       4bf58dd8d48988d1cb941735           Food Truck  40.740104 -73.989658
# ...                          ...                  ...        ...        ...
# 227423  4bf58dd8d48988d1e7931735          Music Venue  40.733596 -74.003139
# 227424  4bf58dd8d48988d16c941735         Burger Joint  40.745719 -73.993720
# 227425  4bf58dd8d48988d103941735       Home (private)  40.854364 -73.883070
# 227426  4bf58dd8d48988d11d941735                  Bar  40.735981 -74.029309
# 227427  4bf58dd8d48988d116941735                  Bar  40.726805 -73.957422
#
#         time_offset                      time  is_weekend  cat_id  clock_sin  \
# 0              -240 2012-04-03 18:00:09+00:00       False       0  -1.000000
# 1              -240 2012-04-03 18:00:25+00:00       False       1  -0.999998
# 2              -240 2012-04-03 18:02:24+00:00       False       2  -0.999945
# 3              -240 2012-04-03 18:02:41+00:00       False       3  -0.999931
# 4              -240 2012-04-03 18:03:00+00:00       False       4  -0.999914
# ...             ...                       ...         ...     ...        ...
# 227423         -300 2013-02-16 02:29:11+00:00        True      16   0.605931
# 227424         -300 2013-02-16 02:31:35+00:00        True      11   0.614228
# 227425         -300 2013-02-16 02:33:16+00:00        True       2   0.620007
# 227426         -300 2013-02-16 02:34:31+00:00        True       9   0.624277
# 227427         -300 2013-02-16 02:35:36+00:00        True       9   0.627963
#
#         clock_cos   day_sin   day_cos  month_sin  month_cos  week_day_sin  \
# 0        0.000654  0.587785  0.809017   0.866025       -0.5      0.781831
# 1        0.001818  0.587785  0.809017   0.866025       -0.5      0.781831
# 2        0.010472  0.587785  0.809017   0.866025       -0.5      0.781831
# 3        0.011708  0.587785  0.809017   0.866025       -0.5      0.781831
# 4        0.013090  0.587785  0.809017   0.866025       -0.5      0.781831
# ...           ...       ...       ...        ...        ...           ...
# 227423   0.795518 -0.207912 -0.978148   0.866025        0.5     -0.974928
# 227424   0.789129 -0.207912 -0.978148   0.866025        0.5     -0.974928
# 227425   0.784596 -0.207912 -0.978148   0.866025        0.5     -0.974928
# 227426   0.781203 -0.207912 -0.978148   0.866025        0.5     -0.974928
# 227427   0.778243 -0.207912 -0.978148   0.866025        0.5     -0.974928
#
#         week_day_cos     location_name
# 0           0.623490     New York City
# 1           0.623490       Bensonhurst
# 2           0.623490     East New York
# 3           0.623490  Long Island City
# 4           0.623490     New York City
# ...              ...               ...
# 227423     -0.222521     New York City
# 227424     -0.222521     New York City
# 227425     -0.222521         The Bronx
# 227426     -0.222521           Hoboken
# 227427     -0.222521  Long Island City
#
# [227428 rows x 20 columns]

# %%
reduced_zones = merged_zones.drop(['venue', 'category_id', 'category_name', 'latitude', 'longitude', 'time_offset', 'time', 'is_weekend', 'cat_id', 'location_name'], axis=1, inplace=False)
reduced_zones
# Out:
#         location_id  user_id  clock_sin  clock_cos   day_sin   day_cos  \
# 0                 0      470  -1.000000   0.000654  0.587785  0.809017
# 1                 1      979  -0.999998   0.001818  0.587785  0.809017
# 2                 2       69  -0.999945   0.010472  0.587785  0.809017
# 3                 3      395  -0.999931   0.011708  0.587785  0.809017
# 4                 0       87  -0.999914   0.013090  0.587785  0.809017
# ...             ...      ...        ...        ...       ...       ...
# 227423            0      688   0.605931   0.795518 -0.207912 -0.978148
# 227424            0      560   0.614228   0.789129 -0.207912 -0.978148
# 227425           33      945   0.620007   0.784596 -0.207912 -0.978148
# 227426           28      671   0.624277   0.781203 -0.207912 -0.978148
# 227427            3      942   0.627963   0.778243 -0.207912 -0.978148
#
#         month_sin  month_cos  week_day_sin  week_day_cos
# 0        0.866025       -0.5      0.781831      0.623490
# 1        0.866025       -0.5      0.781831      0.623490
# 2        0.866025       -0.5      0.781831      0.623490
# 3        0.866025       -0.5      0.781831      0.623490
# 4        0.866025       -0.5      0.781831      0.623490
# ...           ...        ...           ...           ...
# 227423   0.866025        0.5     -0.974928     -0.222521
# 227424   0.866025        0.5     -0.974928     -0.222521
# 227425   0.866025        0.5     -0.974928     -0.222521
# 227426   0.866025        0.5     -0.974928     -0.222521
# 227427   0.866025        0.5     -0.974928     -0.222521
#
# [227428 rows x 10 columns]

# %% [markdown]
# Save the file.

# %%
reduced_zones.to_csv('./4square/processed_transformed_locations.csv', index=False)

# %%
single_user_locations = pd.DataFrame(reduced_zones.loc[reduced_zones.user_id == 185])

# %%
single_user_locations.to_csv('./4square/processed_transformed_locations_185.csv', index=False)
