# %% [markdown]
# # STEP 0 - Preprocessing of the DataSet
#
# Here, the dataset is analyzed and afterwards preprocessed.

# %% [markdown]
# ## Imports

# %%
import pandas as pd
from sqlalchemy import create_engine
import numpy as np

cincinnati = create_engine('sqlite:///cincinnati.db')

# %% [markdown]
# ## Data Analysis
#
# First, we read the dataset into a database in order to get a general understanding. We have the columns:
# * ASSET : Unique indentifier for each vehicle equipped with GPS
# * ASSETNHOOD: The neighborhood the GPS ping was located in
# * DISTANCE_TRAVELED: Distance travelled since last GPS ping
# * HEADING: Direction the vehicle is moveing at the time of the GPS ping
# * ID_HAM_PVMNT_PLYGN: The unique identifier for the street segment the vehicle was on at the time of the GPS ping
# * LATITUDE
# * LOADTS: Time that the data was loaded from the zonar GPS system
# * LONGITUDE
# * ODOMETER: The total distance traveled in miles by the vehicle over its lifetime at the time of the GPS ping.
# * PPOLYLABEL: The name of the street the GPS ping was on
# * REASONS: A coded value for the action or actions that the vehcile is completing at the time of the GPS ping
# * REASONS_TEXT: The decoded action or actions that the vehicle is completing at the time of the GPS ping
# * SPEED: Speed of the vehicle at the time of the GPS ping in miles per hour
# * STREETFROM: The beginning cross street of the street segment that the GPS ping was on
# * STREETTO: The end cross street of the street segment that the GPS ping was on
# * TIME

# %%
df = pd.read_csv("./cincinnati/Year_to_Date_Vehicle_GPS_Data__Department_of_Public_Services.csv", sep=",",)
print(df.head(10))

df.to_sql('cincinnati', con=cincinnati, if_exists="replace")
# Out:
#    ASSET       ASSETNHOOD  DISTANCE_TRAVELED HEADING ID_HAM_PVMNT_PLYGN  \
# 0    317  WEST PRICE HILL                0.1     NNE         S-HAM03339
# 1    483   OVER-THE-RHINE                0.0       S         S-HAM20247
# 2    130  WEST PRICE HILL                0.1       N         S-HAM03328
# 3    276    PADDOCK HILLS                0.6       S         S-HAM30071
# 4    317              NaN                0.5     SSE                NaN
# 5    197  WEST PRICE HILL                0.4       E         S-HAM01835
# 6    380              NaN                0.6       W                NaN
# 7    318              NaN                0.6     SWW         S-HAM52807
# 8     72       CORRYVILLE                1.3       W       I-GJ15223474
# 9    301              NaN                0.2       N                NaN
#
#     LATITUDE        LOADTS  LONGITUDE  ODOMETER  \
# 0  39.108567  2.021010e+13 -84.595120   38216.1
# 1  39.114371  2.021010e+13 -84.512336    8378.6
# 2  39.108329  2.021010e+13 -84.585651   80047.2
# 3  39.169485  2.021010e+13 -84.478541   80496.7
# 4  39.271780  2.021010e+13 -84.597099   38240.8
# 5  39.123420  2.021010e+13 -84.597555   82719.6
# 6  39.142382  2.021010e+13 -84.534018   22686.9
# 7  39.229744  2.021010e+13 -84.636625   15195.5
# 8  39.135497  2.021010e+13 -84.510256  108624.4
# 9  39.271931  2.021010e+13 -84.597054   49629.0
#
#                                           PPOLYLABEL REASONS    REASONS_TEXT  \
# 0                                         HERMOSA AV       9     Motion Stop
# 1                                            MAIN ST      11  Standard Event
# 2                                          SUNSET AV      10    Motion Start
# 3                                         PADDOCK RD      11  Standard Event
# 4                                                NaN      10    Motion Start
# 5                                      PROSPERITY PL      11  Standard Event
# 6                                                NaN       9     Motion Stop
# 7                                      I-275 WB EXWY      11  Standard Event
# 8  VINE ST & E MARTIN LUTHER KING JR DR & JEFFERS...       9     Motion Stop
# 9                                                NaN      11  Standard Event
#
#    SPEED                          STREETFROM                      STREETTO  \
# 0    0.0                       CARNATION CIR                      W 8TH ST
# 1   13.1                        E CLIFTON AV                      PEETE ST
# 2    3.7                            W 8TH ST                ST WILLIAMS AV
# 3   28.6                        TENNESSEE AV  SR 562 EB TO PADDOCK RD RAMP
# 4    4.8                                 NaN                           NaN
# 5   24.2                         ASHBROOK DR                   FERGUSON RD
# 6    0.0                                 NaN                           NaN
# 7   64.6  BLUE ROCK RD TO I-275 WB EXWY RAMP      RRCC WB TO I-275 WB RAMP
# 8    0.0                                 NaN                           NaN
# 9    5.2                                 NaN                           NaN
#
#            TIME
# 0  2.021010e+13
# 1  2.021010e+13
# 2  2.021010e+13
# 3  2.021010e+13
# 4  2.021010e+13
# 5  2.021010e+13
# 6  2.021010e+13
# 7  2.021010e+13
# 8  2.021010e+13
# 9  2.021010e+13

# %%
res=pd.read_sql_query('SELECT count(*) FROM cincinnati', cincinnati)
print(res)
# Out:
#    count(*)
# 0  14502805

# %% [markdown]
# There are 14.502.805 rows in the dataset.

# %%
res=pd.read_sql_query('SELECT ASSET, "count" FROM ' +
            '(SELECT count(ASSET) as "count", ASSET FROM cincinnati GROUP BY ASSET)' +
            'ORDER BY "count" DESC LIMIT 10', cincinnati)

print(res)
# Out:
#    ASSET   count
# 0    153  165652
# 1    445  141781
# 2    450  140814
# 3    261  138953
# 4    255  138790
# 5    487  135507
# 6    228  134339
# 7    449  131684
# 8    210  130801
# 9    300  125974

# %% [markdown]
# Drop all columns that will not be used. (Heading could be interesting for prediction)

# %%
df.drop(['ASSETNHOOD', 'DISTANCE_TRAVELED', 'HEADING', 'ID_HAM_PVMNT_PLYGN', 'LOADTS', 'ODOMETER', 'PPOLYLABEL', 'REASONS', 'REASONS_TEXT', 'SPEED', 'STREETFROM', 'STREETTO'], axis=1, inplace=True)

# %% [markdown]
# Use the 'reverse_geocoder' as before to map the geo coordinates to areas.

# %%
import reverse_geocoder as rg

coords = np.vstack((df["LONGITUDE"].values, df["LATITUDE"].values)).T
coord_array = [(i[1], i[0]) for i in coords]

coord_array
# Out:
# [(39.108567, -84.59512),
#  (39.114371000000006, -84.512336),
#  (39.108329, -84.585651),
#  (39.169484999999995, -84.478541),
#  (39.27178, -84.597099),
#  (39.12342, -84.597555),
#  (39.142382, -84.534018),
#  (39.229744000000004, -84.636625),
#  (39.135496999999994, -84.51025600000001),
#  (39.271931, -84.597054),
#  (39.127959999999995, -84.584665),
#  (39.122991, -84.50836),
#  (39.150419, -84.54406),
#  (39.105145, -84.594658),
#  (39.142476, -84.532933),
#  (39.23418, -84.628637),
#  (39.103159000000005, -84.590361),
#  (39.141309, -84.472409),
#  (39.160609, -84.420905),
#  (39.13527, -84.547977),
#  (39.128796, -84.56833),
#  (39.154592, -84.542417),
#  (39.109907, -84.56071700000001),
#  (39.103915, -84.52386800000001),
#  (39.113063000000004, -84.517336),
#  (39.113926, -84.58570300000001),
#  (39.123020000000004, -84.524399),
#  (39.104432, -84.558114),
#  (39.097587, -84.526093),
#  (39.114027, -84.59715),
#  (39.134031, -84.411172),
#  (39.105009, -84.553302),
#  (39.157294, -84.535366),
#  (39.1388, -84.578929),
#  (39.125173, -84.526675),
#  (39.107547, -84.590335),
#  (39.148972, -84.545076),
#  (39.103908000000004, -84.59877900000001),
#  (39.129919, -84.47269),
#  (39.118431, -84.526942),
#  (39.136666999999996, -84.401861),
#  (39.107794, -84.549718),
#  (39.100798, -84.55371600000001),
#  (39.114509999999996, -84.59214899999999),
#  (39.190847, -84.46745),
#  (39.118368, -84.599149),
#  (39.133736, -84.458795),
#  (39.125397, -84.558627),
#  (39.106725, -84.68706800000001),
#  (39.135692999999996, -84.42242900000001),
#  (39.102515000000004, -84.55314399999999),
#  (39.162177, -84.427853),
#  (39.214013, -84.687576),
#  (39.112204, -84.531163),
#  (39.203086, -84.549446),
#  (39.270357000000004, -84.596899),
#  (39.196265000000004, -84.455865),
#  (39.105343, -84.589044),
#  (39.219536, -84.585909),
#  (39.137971, -84.532881),
#  (39.113882000000004, -84.535838),
#  (39.126748, -84.444629),
#  ...]

# %%
coord_array = [(i[1], i[0]) for i in coords]
search = rg.search(coord_array)
search
# Out:
# [OrderedDict([('lat', '39.12117'),
#               ('lon', '-84.60633'),
#               ('name', 'Covedale'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09145'),
#               ('lon', '-84.49578'),
#               ('name', 'Newport'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Campbell County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.12117'),
#               ('lon', '-84.60633'),
#               ('name', 'Covedale'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.18728'),
#               ('lon', '-84.488'),
#               ('name', 'Elmwood Place'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.25283'),
#               ('lon', '-84.59245'),
#               ('name', 'Northgate'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.12117'),
#               ('lon', '-84.60633'),
#               ('name', 'Covedale'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.167'),
#               ('lon', '-84.49855'),
#               ('name', 'Saint Bernard'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.25922'),
#               ('lon', '-84.61911'),
#               ('name', 'Dry Ridge'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.167'),
#               ('lon', '-84.49855'),
#               ('name', 'Saint Bernard'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.25283'),
#               ('lon', '-84.59245'),
#               ('name', 'Northgate'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.12117'),
#               ('lon', '-84.60633'),
#               ('name', 'Covedale'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.10645'),
#               ('lon', '-84.47883'),
#               ('name', 'Bellevue'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Campbell County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.167'),
#               ('lon', '-84.49855'),
#               ('name', 'Saint Bernard'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.12117'),
#               ('lon', '-84.60633'),
#               ('name', 'Covedale'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.167'),
#               ('lon', '-84.49855'),
#               ('name', 'Saint Bernard'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.25922'),
#               ('lon', '-84.61911'),
#               ('name', 'Dry Ridge'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.12117'),
#               ('lon', '-84.60633'),
#               ('name', 'Covedale'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.15561'),
#               ('lon', '-84.45966'),
#               ('name', 'Norwood'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.14534'),
#               ('lon', '-84.39327'),
#               ('name', 'Fairfax'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.12117'),
#               ('lon', '-84.60633'),
#               ('name', 'Covedale'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.15561'),
#               ('lon', '-84.45966'),
#               ('name', 'Norwood'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.157'),
#               ('lon', '-84.61328'),
#               ('name', 'Cheviot'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.21839'),
#               ('lon', '-84.55078'),
#               ('name', 'North College Hill'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.18839'),
#               ('lon', '-84.59522'),
#               ('name', 'Monfort Heights'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.15561'),
#               ('lon', '-84.45966'),
#               ('name', 'Norwood'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.167'),
#               ('lon', '-84.49855'),
#               ('name', 'Saint Bernard'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.12117'),
#               ('lon', '-84.60633'),
#               ('name', 'Covedale'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.162'),
#               ('lon', '-84.45689'),
#               ('name', 'Cincinnati'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09256'),
#               ('lon', '-84.54744'),
#               ('name', 'Ludlow'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.21839'),
#               ('lon', '-84.55078'),
#               ('name', 'North College Hill'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.21589'),
#               ('lon', '-84.70411'),
#               ('name', 'Miamitown'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09145'),
#               ('lon', '-84.49578'),
#               ('name', 'Newport'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Campbell County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.12117'),
#               ('lon', '-84.60633'),
#               ('name', 'Covedale'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09256'),
#               ('lon', '-84.54744'),
#               ('name', 'Ludlow'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.25283'),
#               ('lon', '-84.59245'),
#               ('name', 'Northgate'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.18839'),
#               ('lon', '-84.59522'),
#               ('name', 'Monfort Heights'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09256'),
#               ('lon', '-84.54744'),
#               ('name', 'Ludlow'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09256'),
#               ('lon', '-84.54744'),
#               ('name', 'Ludlow'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.12117'),
#               ('lon', '-84.60633'),
#               ('name', 'Covedale'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09256'),
#               ('lon', '-84.54744'),
#               ('name', 'Ludlow'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.12117'),
#               ('lon', '-84.60633'),
#               ('name', 'Covedale'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.21839'),
#               ('lon', '-84.55078'),
#               ('name', 'North College Hill'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09256'),
#               ('lon', '-84.54744'),
#               ('name', 'Ludlow'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09256'),
#               ('lon', '-84.54744'),
#               ('name', 'Ludlow'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.14534'),
#               ('lon', '-84.39327'),
#               ('name', 'Fairfax'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.18728'),
#               ('lon', '-84.488'),
#               ('name', 'Elmwood Place'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.15561'),
#               ('lon', '-84.45966'),
#               ('name', 'Norwood'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09256'),
#               ('lon', '-84.54744'),
#               ('name', 'Ludlow'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.12117'),
#               ('lon', '-84.60633'),
#               ('name', 'Covedale'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09145'),
#               ('lon', '-84.49578'),
#               ('name', 'Newport'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Campbell County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.12117'),
#               ('lon', '-84.60633'),
#               ('name', 'Covedale'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09145'),
#               ('lon', '-84.49578'),
#               ('name', 'Newport'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Campbell County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09256'),
#               ('lon', '-84.54744'),
#               ('name', 'Ludlow'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09145'),
#               ('lon', '-84.49578'),
#               ('name', 'Newport'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Campbell County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.167'),
#               ('lon', '-84.49855'),
#               ('name', 'Saint Bernard'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.25283'),
#               ('lon', '-84.59245'),
#               ('name', 'Northgate'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.18839'),
#               ('lon', '-84.59522'),
#               ('name', 'Monfort Heights'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.12117'),
#               ('lon', '-84.60633'),
#               ('name', 'Covedale'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.167'),
#               ('lon', '-84.49855'),
#               ('name', 'Saint Bernard'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09256'),
#               ('lon', '-84.54744'),
#               ('name', 'Ludlow'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09256'),
#               ('lon', '-84.54744'),
#               ('name', 'Ludlow'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.167'),
#               ('lon', '-84.49855'),
#               ('name', 'Saint Bernard'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.11284'),
#               ('lon', '-84.47272'),
#               ('name', 'Dayton'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Campbell County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.167'),
#               ('lon', '-84.49855'),
#               ('name', 'Saint Bernard'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.18728'),
#               ('lon', '-84.488'),
#               ('name', 'Elmwood Place'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.11284'),
#               ('lon', '-84.47272'),
#               ('name', 'Dayton'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Campbell County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09256'),
#               ('lon', '-84.54744'),
#               ('name', 'Ludlow'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.18589'),
#               ('lon', '-84.65134'),
#               ('name', 'Dent'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.12117'),
#               ('lon', '-84.60633'),
#               ('name', 'Covedale'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.18839'),
#               ('lon', '-84.59522'),
#               ('name', 'Monfort Heights'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.15561'),
#               ('lon', '-84.45966'),
#               ('name', 'Norwood'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.167'),
#               ('lon', '-84.49855'),
#               ('name', 'Saint Bernard'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.10645'),
#               ('lon', '-84.47883'),
#               ('name', 'Bellevue'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Campbell County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.12117'),
#               ('lon', '-84.60633'),
#               ('name', 'Covedale'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.18589'),
#               ('lon', '-84.65134'),
#               ('name', 'Dent'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09256'),
#               ('lon', '-84.54744'),
#               ('name', 'Ludlow'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.14534'),
#               ('lon', '-84.39327'),
#               ('name', 'Fairfax'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.18589'),
#               ('lon', '-84.65134'),
#               ('name', 'Dent'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09256'),
#               ('lon', '-84.54744'),
#               ('name', 'Ludlow'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.167'),
#               ('lon', '-84.49855'),
#               ('name', 'Saint Bernard'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.167'),
#               ('lon', '-84.49855'),
#               ('name', 'Saint Bernard'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.14534'),
#               ('lon', '-84.39327'),
#               ('name', 'Fairfax'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.167'),
#               ('lon', '-84.49855'),
#               ('name', 'Saint Bernard'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.167'),
#               ('lon', '-84.49855'),
#               ('name', 'Saint Bernard'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.18839'),
#               ('lon', '-84.59522'),
#               ('name', 'Monfort Heights'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.21589'),
#               ('lon', '-84.70411'),
#               ('name', 'Miamitown'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.10645'),
#               ('lon', '-84.47883'),
#               ('name', 'Bellevue'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Campbell County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.167'),
#               ('lon', '-84.49855'),
#               ('name', 'Saint Bernard'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09256'),
#               ('lon', '-84.54744'),
#               ('name', 'Ludlow'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.167'),
#               ('lon', '-84.49855'),
#               ('name', 'Saint Bernard'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.11284'),
#               ('lon', '-84.47272'),
#               ('name', 'Dayton'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Campbell County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.18839'),
#               ('lon', '-84.59522'),
#               ('name', 'Monfort Heights'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09145'),
#               ('lon', '-84.49578'),
#               ('name', 'Newport'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Campbell County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.12117'),
#               ('lon', '-84.60633'),
#               ('name', 'Covedale'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.167'),
#               ('lon', '-84.49855'),
#               ('name', 'Saint Bernard'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.14534'),
#               ('lon', '-84.39327'),
#               ('name', 'Fairfax'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.10506'),
#               ('lon', '-84.72439'),
#               ('name', 'Francisville'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Boone County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.20034'),
#               ('lon', '-84.5205'),
#               ('name', 'Finneytown'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.12117'),
#               ('lon', '-84.60633'),
#               ('name', 'Covedale'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09256'),
#               ('lon', '-84.54744'),
#               ('name', 'Ludlow'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.18728'),
#               ('lon', '-84.488'),
#               ('name', 'Elmwood Place'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09256'),
#               ('lon', '-84.54744'),
#               ('name', 'Ludlow'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.157'),
#               ('lon', '-84.61328'),
#               ('name', 'Cheviot'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09256'),
#               ('lon', '-84.54744'),
#               ('name', 'Ludlow'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.167'),
#               ('lon', '-84.49855'),
#               ('name', 'Saint Bernard'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.12117'),
#               ('lon', '-84.60633'),
#               ('name', 'Covedale'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.22311'),
#               ('lon', '-84.58689'),
#               ('name', 'Groesbeck'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.167'),
#               ('lon', '-84.49855'),
#               ('name', 'Saint Bernard'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09256'),
#               ('lon', '-84.54744'),
#               ('name', 'Ludlow'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09145'),
#               ('lon', '-84.49578'),
#               ('name', 'Newport'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Campbell County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09145'),
#               ('lon', '-84.49578'),
#               ('name', 'Newport'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Campbell County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.167'),
#               ('lon', '-84.49855'),
#               ('name', 'Saint Bernard'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09145'),
#               ('lon', '-84.49578'),
#               ('name', 'Newport'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Campbell County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09256'),
#               ('lon', '-84.54744'),
#               ('name', 'Ludlow'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09256'),
#               ('lon', '-84.54744'),
#               ('name', 'Ludlow'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.11284'),
#               ('lon', '-84.47272'),
#               ('name', 'Dayton'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Campbell County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.167'),
#               ('lon', '-84.49855'),
#               ('name', 'Saint Bernard'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.12117'),
#               ('lon', '-84.60633'),
#               ('name', 'Covedale'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09256'),
#               ('lon', '-84.54744'),
#               ('name', 'Ludlow'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.167'),
#               ('lon', '-84.49855'),
#               ('name', 'Saint Bernard'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09256'),
#               ('lon', '-84.54744'),
#               ('name', 'Ludlow'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.21839'),
#               ('lon', '-84.55078'),
#               ('name', 'North College Hill'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.19284'),
#               ('lon', '-84.4005'),
#               ('name', 'Silverton'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09145'),
#               ('lon', '-84.49578'),
#               ('name', 'Newport'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Campbell County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.25283'),
#               ('lon', '-84.59245'),
#               ('name', 'Northgate'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.21589'),
#               ('lon', '-84.70411'),
#               ('name', 'Miamitown'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.25283'),
#               ('lon', '-84.59245'),
#               ('name', 'Northgate'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.167'),
#               ('lon', '-84.49855'),
#               ('name', 'Saint Bernard'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.167'),
#               ('lon', '-84.49855'),
#               ('name', 'Saint Bernard'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.25283'),
#               ('lon', '-84.59245'),
#               ('name', 'Northgate'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.167'),
#               ('lon', '-84.49855'),
#               ('name', 'Saint Bernard'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.15561'),
#               ('lon', '-84.45966'),
#               ('name', 'Norwood'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09256'),
#               ('lon', '-84.54744'),
#               ('name', 'Ludlow'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.167'),
#               ('lon', '-84.49855'),
#               ('name', 'Saint Bernard'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09256'),
#               ('lon', '-84.54744'),
#               ('name', 'Ludlow'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.167'),
#               ('lon', '-84.49855'),
#               ('name', 'Saint Bernard'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.11006'),
#               ('lon', '-84.37994'),
#               ('name', 'Turpin Hills'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.21589'),
#               ('lon', '-84.70411'),
#               ('name', 'Miamitown'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.167'),
#               ('lon', '-84.49855'),
#               ('name', 'Saint Bernard'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.167'),
#               ('lon', '-84.49855'),
#               ('name', 'Saint Bernard'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.18589'),
#               ('lon', '-84.65134'),
#               ('name', 'Dent'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.12117'),
#               ('lon', '-84.60633'),
#               ('name', 'Covedale'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.08367'),
#               ('lon', '-84.50855'),
#               ('name', 'Covington'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09256'),
#               ('lon', '-84.54744'),
#               ('name', 'Ludlow'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.167'),
#               ('lon', '-84.49855'),
#               ('name', 'Saint Bernard'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.167'),
#               ('lon', '-84.49855'),
#               ('name', 'Saint Bernard'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.12117'),
#               ('lon', '-84.60633'),
#               ('name', 'Covedale'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.167'),
#               ('lon', '-84.49855'),
#               ('name', 'Saint Bernard'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09256'),
#               ('lon', '-84.54744'),
#               ('name', 'Ludlow'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.12117'),
#               ('lon', '-84.60633'),
#               ('name', 'Covedale'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.12117'),
#               ('lon', '-84.60633'),
#               ('name', 'Covedale'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.167'),
#               ('lon', '-84.49855'),
#               ('name', 'Saint Bernard'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.12117'),
#               ('lon', '-84.60633'),
#               ('name', 'Covedale'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.25283'),
#               ('lon', '-84.59245'),
#               ('name', 'Northgate'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.10645'),
#               ('lon', '-84.47883'),
#               ('name', 'Bellevue'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Campbell County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.11284'),
#               ('lon', '-84.47272'),
#               ('name', 'Dayton'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Campbell County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.06339'),
#               ('lon', '-84.593'),
#               ('name', 'Villa Hills'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.18728'),
#               ('lon', '-84.44633'),
#               ('name', 'Golf Manor'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.18589'),
#               ('lon', '-84.65134'),
#               ('name', 'Dent'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09256'),
#               ('lon', '-84.54744'),
#               ('name', 'Ludlow'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09145'),
#               ('lon', '-84.49578'),
#               ('name', 'Newport'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Campbell County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.12117'),
#               ('lon', '-84.60633'),
#               ('name', 'Covedale'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.25283'),
#               ('lon', '-84.59245'),
#               ('name', 'Northgate'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09256'),
#               ('lon', '-84.54744'),
#               ('name', 'Ludlow'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09256'),
#               ('lon', '-84.54744'),
#               ('name', 'Ludlow'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.21589'),
#               ('lon', '-84.70411'),
#               ('name', 'Miamitown'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.08367'),
#               ('lon', '-84.50855'),
#               ('name', 'Covington'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09145'),
#               ('lon', '-84.49578'),
#               ('name', 'Newport'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Campbell County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.14534'),
#               ('lon', '-84.39327'),
#               ('name', 'Fairfax'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.15561'),
#               ('lon', '-84.45966'),
#               ('name', 'Norwood'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.20034'),
#               ('lon', '-84.5205'),
#               ('name', 'Finneytown'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.18728'),
#               ('lon', '-84.488'),
#               ('name', 'Elmwood Place'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09256'),
#               ('lon', '-84.54744'),
#               ('name', 'Ludlow'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09145'),
#               ('lon', '-84.49578'),
#               ('name', 'Newport'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Campbell County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09256'),
#               ('lon', '-84.54744'),
#               ('name', 'Ludlow'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.18589'),
#               ('lon', '-84.65134'),
#               ('name', 'Dent'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.167'),
#               ('lon', '-84.49855'),
#               ('name', 'Saint Bernard'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09256'),
#               ('lon', '-84.54744'),
#               ('name', 'Ludlow'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.167'),
#               ('lon', '-84.49855'),
#               ('name', 'Saint Bernard'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.10506'),
#               ('lon', '-84.72439'),
#               ('name', 'Francisville'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Boone County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.167'),
#               ('lon', '-84.49855'),
#               ('name', 'Saint Bernard'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.18839'),
#               ('lon', '-84.59522'),
#               ('name', 'Monfort Heights'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.08367'),
#               ('lon', '-84.50855'),
#               ('name', 'Covington'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09256'),
#               ('lon', '-84.54744'),
#               ('name', 'Ludlow'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09256'),
#               ('lon', '-84.54744'),
#               ('name', 'Ludlow'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09145'),
#               ('lon', '-84.49578'),
#               ('name', 'Newport'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Campbell County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09256'),
#               ('lon', '-84.54744'),
#               ('name', 'Ludlow'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.11284'),
#               ('lon', '-84.47272'),
#               ('name', 'Dayton'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Campbell County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09256'),
#               ('lon', '-84.54744'),
#               ('name', 'Ludlow'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.08367'),
#               ('lon', '-84.50855'),
#               ('name', 'Covington'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09256'),
#               ('lon', '-84.54744'),
#               ('name', 'Ludlow'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.14534'),
#               ('lon', '-84.39327'),
#               ('name', 'Fairfax'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.08367'),
#               ('lon', '-84.50855'),
#               ('name', 'Covington'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.167'),
#               ('lon', '-84.49855'),
#               ('name', 'Saint Bernard'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09284'),
#               ('lon', '-84.61272'),
#               ('name', 'Delhi Hills'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.12117'),
#               ('lon', '-84.60633'),
#               ('name', 'Covedale'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.167'),
#               ('lon', '-84.49855'),
#               ('name', 'Saint Bernard'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09145'),
#               ('lon', '-84.49578'),
#               ('name', 'Newport'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Campbell County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.167'),
#               ('lon', '-84.49855'),
#               ('name', 'Saint Bernard'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.11284'),
#               ('lon', '-84.47272'),
#               ('name', 'Dayton'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Campbell County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.21839'),
#               ('lon', '-84.55078'),
#               ('name', 'North College Hill'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.10506'),
#               ('lon', '-84.72439'),
#               ('name', 'Francisville'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Boone County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.167'),
#               ('lon', '-84.49855'),
#               ('name', 'Saint Bernard'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.10506'),
#               ('lon', '-84.72439'),
#               ('name', 'Francisville'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Boone County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.12117'),
#               ('lon', '-84.60633'),
#               ('name', 'Covedale'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.167'),
#               ('lon', '-84.49855'),
#               ('name', 'Saint Bernard'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.25283'),
#               ('lon', '-84.59245'),
#               ('name', 'Northgate'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09256'),
#               ('lon', '-84.54744'),
#               ('name', 'Ludlow'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09256'),
#               ('lon', '-84.54744'),
#               ('name', 'Ludlow'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.12117'),
#               ('lon', '-84.60633'),
#               ('name', 'Covedale'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09256'),
#               ('lon', '-84.54744'),
#               ('name', 'Ludlow'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09256'),
#               ('lon', '-84.54744'),
#               ('name', 'Ludlow'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.167'),
#               ('lon', '-84.49855'),
#               ('name', 'Saint Bernard'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.167'),
#               ('lon', '-84.49855'),
#               ('name', 'Saint Bernard'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.15561'),
#               ('lon', '-84.45966'),
#               ('name', 'Norwood'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.157'),
#               ('lon', '-84.61328'),
#               ('name', 'Cheviot'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09256'),
#               ('lon', '-84.54744'),
#               ('name', 'Ludlow'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.25283'),
#               ('lon', '-84.59245'),
#               ('name', 'Northgate'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09256'),
#               ('lon', '-84.54744'),
#               ('name', 'Ludlow'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.12117'),
#               ('lon', '-84.60633'),
#               ('name', 'Covedale'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.08367'),
#               ('lon', '-84.50855'),
#               ('name', 'Covington'),
# ...
#               ('name', 'Ludlow'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.12117'),
#               ('lon', '-84.60633'),
#               ('name', 'Covedale'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09256'),
#               ('lon', '-84.54744'),
#               ('name', 'Ludlow'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.157'),
#               ('lon', '-84.61328'),
#               ('name', 'Cheviot'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.08367'),
#               ('lon', '-84.50855'),
#               ('name', 'Covington'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09256'),
#               ('lon', '-84.54744'),
#               ('name', 'Ludlow'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.12117'),
#               ('lon', '-84.60633'),
#               ('name', 'Covedale'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.19284'),
#               ('lon', '-84.4005'),
#               ('name', 'Silverton'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09256'),
#               ('lon', '-84.54744'),
#               ('name', 'Ludlow'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.167'),
#               ('lon', '-84.49855'),
#               ('name', 'Saint Bernard'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09256'),
#               ('lon', '-84.54744'),
#               ('name', 'Ludlow'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.167'),
#               ('lon', '-84.49855'),
#               ('name', 'Saint Bernard'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09256'),
#               ('lon', '-84.54744'),
#               ('name', 'Ludlow'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.167'),
#               ('lon', '-84.49855'),
#               ('name', 'Saint Bernard'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09256'),
#               ('lon', '-84.54744'),
#               ('name', 'Ludlow'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.12117'),
#               ('lon', '-84.60633'),
#               ('name', 'Covedale'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.12117'),
#               ('lon', '-84.60633'),
#               ('name', 'Covedale'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.14534'),
#               ('lon', '-84.39327'),
#               ('name', 'Fairfax'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.18839'),
#               ('lon', '-84.59522'),
#               ('name', 'Monfort Heights'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.167'),
#               ('lon', '-84.49855'),
#               ('name', 'Saint Bernard'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.20034'),
#               ('lon', '-84.5205'),
#               ('name', 'Finneytown'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.167'),
#               ('lon', '-84.49855'),
#               ('name', 'Saint Bernard'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.25922'),
#               ('lon', '-84.61911'),
#               ('name', 'Dry Ridge'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.15561'),
#               ('lon', '-84.45966'),
#               ('name', 'Norwood'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.167'),
#               ('lon', '-84.49855'),
#               ('name', 'Saint Bernard'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09256'),
#               ('lon', '-84.54744'),
#               ('name', 'Ludlow'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.12117'),
#               ('lon', '-84.60633'),
#               ('name', 'Covedale'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.157'),
#               ('lon', '-84.61328'),
#               ('name', 'Cheviot'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09256'),
#               ('lon', '-84.54744'),
#               ('name', 'Ludlow'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09256'),
#               ('lon', '-84.54744'),
#               ('name', 'Ludlow'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09256'),
#               ('lon', '-84.54744'),
#               ('name', 'Ludlow'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09256'),
#               ('lon', '-84.54744'),
#               ('name', 'Ludlow'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.12117'),
#               ('lon', '-84.60633'),
#               ('name', 'Covedale'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.167'),
#               ('lon', '-84.49855'),
#               ('name', 'Saint Bernard'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09256'),
#               ('lon', '-84.54744'),
#               ('name', 'Ludlow'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.08367'),
#               ('lon', '-84.50855'),
#               ('name', 'Covington'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09145'),
#               ('lon', '-84.49578'),
#               ('name', 'Newport'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Campbell County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.12117'),
#               ('lon', '-84.60633'),
#               ('name', 'Covedale'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09256'),
#               ('lon', '-84.54744'),
#               ('name', 'Ludlow'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09256'),
#               ('lon', '-84.54744'),
#               ('name', 'Ludlow'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09256'),
#               ('lon', '-84.54744'),
#               ('name', 'Ludlow'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.12117'),
#               ('lon', '-84.60633'),
#               ('name', 'Covedale'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.14534'),
#               ('lon', '-84.39327'),
#               ('name', 'Fairfax'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09256'),
#               ('lon', '-84.54744'),
#               ('name', 'Ludlow'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.167'),
#               ('lon', '-84.49855'),
#               ('name', 'Saint Bernard'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.12117'),
#               ('lon', '-84.60633'),
#               ('name', 'Covedale'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09256'),
#               ('lon', '-84.54744'),
#               ('name', 'Ludlow'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.12117'),
#               ('lon', '-84.60633'),
#               ('name', 'Covedale'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.167'),
#               ('lon', '-84.49855'),
#               ('name', 'Saint Bernard'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09284'),
#               ('lon', '-84.61272'),
#               ('name', 'Delhi Hills'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.11284'),
#               ('lon', '-84.47272'),
#               ('name', 'Dayton'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Campbell County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09256'),
#               ('lon', '-84.54744'),
#               ('name', 'Ludlow'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.14534'),
#               ('lon', '-84.39327'),
#               ('name', 'Fairfax'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09256'),
#               ('lon', '-84.54744'),
#               ('name', 'Ludlow'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09256'),
#               ('lon', '-84.54744'),
#               ('name', 'Ludlow'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.12117'),
#               ('lon', '-84.60633'),
#               ('name', 'Covedale'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.18728'),
#               ('lon', '-84.488'),
#               ('name', 'Elmwood Place'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.12117'),
#               ('lon', '-84.60633'),
#               ('name', 'Covedale'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.15561'),
#               ('lon', '-84.45966'),
#               ('name', 'Norwood'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09256'),
#               ('lon', '-84.54744'),
#               ('name', 'Ludlow'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.10506'),
#               ('lon', '-84.72439'),
#               ('name', 'Francisville'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Boone County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.14534'),
#               ('lon', '-84.39327'),
#               ('name', 'Fairfax'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09256'),
#               ('lon', '-84.54744'),
#               ('name', 'Ludlow'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.162'),
#               ('lon', '-84.45689'),
#               ('name', 'Cincinnati'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.21589'),
#               ('lon', '-84.70411'),
#               ('name', 'Miamitown'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09256'),
#               ('lon', '-84.54744'),
#               ('name', 'Ludlow'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.21839'),
#               ('lon', '-84.55078'),
#               ('name', 'North College Hill'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.25283'),
#               ('lon', '-84.59245'),
#               ('name', 'Northgate'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.18728'),
#               ('lon', '-84.44633'),
#               ('name', 'Golf Manor'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.12117'),
#               ('lon', '-84.60633'),
#               ('name', 'Covedale'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.22311'),
#               ('lon', '-84.58689'),
#               ('name', 'Groesbeck'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.167'),
#               ('lon', '-84.49855'),
#               ('name', 'Saint Bernard'),
#               ('admin1', 'Ohio'),
#               ('admin2', 'Hamilton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.09256'),
#               ('lon', '-84.54744'),
#               ('name', 'Ludlow'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Kenton County'),
#               ('cc', 'US')]),
#  OrderedDict([('lat', '39.11284'),
#               ('lon', '-84.47272'),
#               ('name', 'Dayton'),
#               ('admin1', 'Kentucky'),
#               ('admin2', 'Campbell County'),
#               ('cc', 'US')]),
#  ...]

# %%
values= []
for i in range(len(search)):
    values.append(search[i])

coord_search_df = pd.DataFrame(values)
coord_search_df
# Out:
#                lat        lon           name    admin1           admin2  cc
# 0         39.12117  -84.60633       Covedale      Ohio  Hamilton County  US
# 1         39.09145  -84.49578        Newport  Kentucky  Campbell County  US
# 2         39.12117  -84.60633       Covedale      Ohio  Hamilton County  US
# 3         39.18728    -84.488  Elmwood Place      Ohio  Hamilton County  US
# 4         39.25283  -84.59245      Northgate      Ohio  Hamilton County  US
# ...            ...        ...            ...       ...              ...  ..
# 14502800  39.09256  -84.54744         Ludlow  Kentucky    Kenton County  US
# 14502801    39.167  -84.49855  Saint Bernard      Ohio  Hamilton County  US
# 14502802    39.167  -84.49855  Saint Bernard      Ohio  Hamilton County  US
# 14502803    39.167  -84.49855  Saint Bernard      Ohio  Hamilton County  US
# 14502804  39.15561  -84.45966        Norwood      Ohio  Hamilton County  US
#
# [14502805 rows x 6 columns]

# %%
print("Name : ", coord_search_df.name.nunique())
print("Admin1 : ", coord_search_df.admin1.nunique())
print("Admin2 : ", coord_search_df.admin2.nunique())
# Out:
# Name :  166
# Admin1 :  6
# Admin2 :  26

# %% [markdown]
# Now, the dataset is joined with the areas.

# %%
zones = df.copy()
zones['area_name'] = coord_search_df['name']
zones
# Out:
#           ASSET   LATITUDE  LONGITUDE          TIME      area_name
# 0           317  39.108567 -84.595120  2.021010e+13       Covedale
# 1           483  39.114371 -84.512336  2.021010e+13        Newport
# 2           130  39.108329 -84.585651  2.021010e+13       Covedale
# 3           276  39.169485 -84.478541  2.021010e+13  Elmwood Place
# 4           317  39.271780 -84.597099  2.021010e+13      Northgate
# ...         ...        ...        ...           ...            ...
# 14502800    446  39.137762 -84.535466  2.021010e+13         Ludlow
# 14502801    228  39.157666 -84.547908  2.021010e+13  Saint Bernard
# 14502802    446  39.144670 -84.525625  2.021010e+13  Saint Bernard
# 14502803    258  39.139572 -84.533399  2.021010e+13  Saint Bernard
# 14502804    262  39.133676 -84.434501  2.021010e+13        Norwood
#
# [14502805 rows x 5 columns]

# %%
count = zones.area_name.value_counts()
count
# Out:
# Saint Bernard           3107116
# Ludlow                  1895889
# Covedale                1190999
# Fairfax                  934287
# Norwood                  681201
#                          ...
# Edgewood                      2
# Osgood                        2
# Saint Peter                   2
# Nantucket                     1
# Country Squire Lakes          1
# Name: area_name, Length: 166, dtype: int64

# %% [markdown]
# The dataset got so many records, so it is fine to drop the least used zones.
# Only the 100 most used zones are kept

# %%
idx = count.loc[count.index[:100]].index
zones = zones.loc[zones.area_name.isin(idx)]

# %%
print("Name : ", zones.area_name.nunique())
print("Row Count : ", len(zones))
# Out:
# Name :  100
# Row Count :  14500904

# %% [markdown]
# Previously: 14.502.805
# Now: 14.500.904
# Approximately 2000 rows were lost by dropping all the records with the 61 least used areas.

# %%
#disable warning
pd.options.mode.chained_assignment = None
zones['location_id'] = zones.groupby('area_name', sort=False).ngroup()
zones.head(10)
# Out:
#    ASSET   LATITUDE  LONGITUDE          TIME      area_name  location_id
# 0    317  39.108567 -84.595120  2.021010e+13       Covedale            0
# 1    483  39.114371 -84.512336  2.021010e+13        Newport            1
# 2    130  39.108329 -84.585651  2.021010e+13       Covedale            0
# 3    276  39.169485 -84.478541  2.021010e+13  Elmwood Place            2
# 4    317  39.271780 -84.597099  2.021010e+13      Northgate            3
# 5    197  39.123420 -84.597555  2.021010e+13       Covedale            0
# 6    380  39.142382 -84.534018  2.021010e+13  Saint Bernard            4
# 7    318  39.229744 -84.636625  2.021010e+13      Dry Ridge            5
# 8     72  39.135497 -84.510256  2.021010e+13  Saint Bernard            4
# 9    301  39.271931 -84.597054  2.021010e+13      Northgate            3

# %%
# convert the 'Date' column to datetime format
# 20210104085517 -> 2021-01-04 08:55.17
# 20210104131316 -> 2021-01-04 13:13.16
zones['TIME'] = zones['TIME'].astype(str).str.slice(0,13)
zones['time']= pd.to_datetime(zones['TIME'], format='%Y%m%d%H%M%S')
zones.head(10)
# Out:
#    ASSET   LATITUDE  LONGITUDE           TIME      area_name  location_id  \
# 0    317  39.108567 -84.595120  2021010408551       Covedale            0
# 1    483  39.114371 -84.512336  2021010409313        Newport            1
# 2    130  39.108329 -84.585651  2021010413131       Covedale            0
# 3    276  39.169485 -84.478541  2021010411241  Elmwood Place            2
# 4    317  39.271780 -84.597099  2021010413225      Northgate            3
# 5    197  39.123420 -84.597555  2021010409362       Covedale            0
# 6    380  39.142382 -84.534018  2021010401444  Saint Bernard            4
# 7    318  39.229744 -84.636625  2021010413100      Dry Ridge            5
# 8     72  39.135497 -84.510256  2021010408292  Saint Bernard            4
# 9    301  39.271931 -84.597054  2021010412103      Northgate            3
#
#                  time
# 0 2021-01-04 08:55:01
# 1 2021-01-04 09:31:03
# 2 2021-01-04 13:13:01
# 3 2021-01-04 11:24:01
# 4 2021-01-04 13:22:05
# 5 2021-01-04 09:36:02
# 6 2021-01-04 01:44:04
# 7 2021-01-04 13:10:00
# 8 2021-01-04 08:29:02
# 9 2021-01-04 12:10:03

# %%
count_nan = zones['time'].isnull().sum() + zones['location_id'].isnull().sum() + zones['ASSET'].isnull().sum()

# printing the number of values present in the columns time, location_id and ASSET
print('Number of NaN values present: ' + str(count_nan))
# Out:
# Number of NaN values present: 0

# %%
def is_weekend(week_day):
    return week_day > 4

# %% [markdown]
# The data is split in temporal components and a sin-/cos-transformation is executed.

# %%
zones["month"] = zones.time.dt.month
zones["day"] = zones.time.dt.day
zones["clock"] = zones.time.dt.hour + zones.time.dt.minute/60 + zones.time.dt.second/3600
zones["week_day"] = zones.time.dt.dayofweek
zones["is_weekend"] = zones.apply(lambda x: is_weekend(x["week_day"]), axis=1)

# %%
zones['clock_sin'] = np.sin(2 * np.pi * zones['clock']/24.0)
zones['clock_cos'] = np.cos(2 * np.pi * zones['clock']/24.0)
zones['day_sin'] = np.sin(2 * np.pi * zones['day']/30.0)
zones['day_cos'] = np.cos(2 * np.pi * zones['day']/30.0)
zones['month_sin'] = np.sin(2 * np.pi * zones['month']/12.0)
zones['month_cos'] = np.cos(2 * np.pi * zones['month']/12.0)
zones['week_day_sin'] = np.sin(2 * np.pi * zones['week_day']/7.0)
zones['week_day_cos'] = np.cos(2 * np.pi * zones['week_day']/7.0)

# %% [markdown]
# Now, the columns that are not needed any more will be dropped.

# %%
zones.drop(['LATITUDE', 'LONGITUDE', 'TIME', 'time', 'month', 'day', 'clock', 'week_day', 'area_name'], axis=1, inplace=True)

# %%
def move_first(df, column_name):
    fc = df.pop(column_name)
    df.insert(0, column_name, fc)

# %%
move_first(zones, 'location_id')

# %%
zones.rename(columns={'ASSET':'vehicle_id'}, inplace=True)

# %%
zones.head(10)
# Out:
#    location_id  vehicle_id  is_weekend  clock_sin  clock_cos   day_sin  \
# 0            0         317       False   0.722314  -0.691566  0.743145
# 1            1         483       False   0.605120  -0.796134  0.743145
# 2            0         130       False  -0.313233  -0.949676  0.743145
# 3            2         276       False   0.156363  -0.987700  0.743145
# 4            3         317       False  -0.350548  -0.936545  0.743145
# 5            0         197       False   0.587668  -0.809102  0.743145
# 6            4         380       False   0.438633   0.898666  0.743145
# 7            5         318       False  -0.300706  -0.953717  0.743145
# 8            4          72       False   0.795914  -0.605410  0.743145
# 9            3         301       False  -0.043837  -0.999039  0.743145
#
#     day_cos  month_sin  month_cos  week_day_sin  week_day_cos
# 0  0.669131        0.5   0.866025           0.0           1.0
# 1  0.669131        0.5   0.866025           0.0           1.0
# 2  0.669131        0.5   0.866025           0.0           1.0
# 3  0.669131        0.5   0.866025           0.0           1.0
# 4  0.669131        0.5   0.866025           0.0           1.0
# 5  0.669131        0.5   0.866025           0.0           1.0
# 6  0.669131        0.5   0.866025           0.0           1.0
# 7  0.669131        0.5   0.866025           0.0           1.0
# 8  0.669131        0.5   0.866025           0.0           1.0
# 9  0.669131        0.5   0.866025           0.0           1.0

# %%
zones.to_csv('././cincinnati/cincinatti_zones.csv', index=False)

# %%
single_vehicle = pd.DataFrame(zones.loc[zones.vehicle_id == 153])

# %%
single_vehicle.head(10)
# Out:
#      location_id  vehicle_id  is_weekend  clock_sin  clock_cos   day_sin  \
# 235            4         153       False  -0.725424  -0.688302  0.743145
# 257           10         153       False  -0.619379  -0.785092  0.743145
# 273            4         153       False   0.378379  -0.925651  0.743145
# 356            4         153       False   0.635798  -0.771856  0.743145
# 430           11         153       False  -0.492424  -0.870356  0.743145
# 567            4         153       False   0.476903  -0.878956  0.743145
# 573           18         153       False  -0.697999  -0.716099  0.743145
# 737           10         153       False   0.121725  -0.992564  0.743145
# 771           10         153       False   0.004363  -0.999990  0.743145
# 834           13         153       False   0.618923  -0.785452  0.743145
#
#       day_cos  month_sin  month_cos  week_day_sin  week_day_cos
# 235  0.669131        0.5   0.866025           0.0           1.0
# 257  0.669131        0.5   0.866025           0.0           1.0
# 273  0.669131        0.5   0.866025           0.0           1.0
# 356  0.669131        0.5   0.866025           0.0           1.0
# 430  0.669131        0.5   0.866025           0.0           1.0
# 567  0.669131        0.5   0.866025           0.0           1.0
# 573  0.669131        0.5   0.866025           0.0           1.0
# 737  0.669131        0.5   0.866025           0.0           1.0
# 771  0.669131        0.5   0.866025           0.0           1.0
# 834  0.669131        0.5   0.866025           0.0           1.0

# %%
single_vehicle.to_csv('././cincinnati/cincinatti_zones_153.csv', index=False)
